# %% [markdown]
# # Electric Vehicle Charging Optimization Using Mixed Integer Linear Programming
#
# ## Table of Contents
# 1. [Introduction](#introduction)
# 2. [Problem Formulation](#problem-formulation)
# 3. [Mathematical Model](#mathematical-model)
# 4. [Implementation](#implementation)
# 5. [Real Data Analysis](#real-data-analysis)
# 6. [Results and Discussion](#results-and-discussion)
#
# ---
#
# ## 1. Introduction {#introduction}
#
# Electric vehicle (EV) charging optimization is crucial for minimizing electricity costs while maintaining charging requirements. This tutorial demonstrates how to formulate and solve an EV charging optimization problem using Mixed Integer Linear Programming (MILP).
#
# ### Key Objectives:
# - **Minimize total electricity costs** (energy charges + demand charges)
# - **Satisfy charging requirements** for all EV sessions
# - **Respect time constraints** and charging session windows
# - **Optimize power level selection** between 1.2 kW and 7.0 kW
# - **Optimize using 15-minute time intervals**
#
# ### L2 Charging Station Model:
# This tutorial models a **Level 2 (L2) AC charging station** with continuously controllable power output:
# - **Continuous Power Range**: 1.2 kW ≤ P ≤ 7.0 kW
# - **Optimal Power Selection**: The optimizer determines the exact optimal power level for each 15-minute charging block
# - **Precise Control**: Each charging block can use any power level within the continuous range
#
# This continuous power level approach reflects advanced L2 charging infrastructure capabilities where power can be continuously modulated through electronic control, providing maximum operational flexibility and cost optimization opportunities while maintaining realistic physical constraints.
#
# ### Background
# This implementation is based on research conducted at Lawrence Berkeley National Laboratory analyzing smart charging strategies for the AlCoPark garage dataset, which included over 20,000 charging sessions from 2013-2017.
#
# ---
#
# ## 2. Problem Formulation {#problem-formulation}
#
# ### Problem Statement
# Given a set of EV charging sessions with arrival/departure times and energy requirements, determine the optimal charging schedule to minimize total electricity costs under Time-of-Use (TOU) pricing.
#
# ### Key Parameters:
# - **Time horizon**: From start time to (day+1) 08:00
# - **Time discretization**: 15-minute intervals
# - **Pricing structure**: PG&E E-19 rate schedule
# - **Charging constraints**: Session time windows and energy requirements
#
# ### Decision Variables:
# - $x_{i,t} \in \{0,1\}$: Binary variable indicating if session $i$ is charging at time slot $t$
# - $P_{i,t} \in [1.2, 7.0]$: Continuous power level (kW) for session $i$ at time slot $t$
# - $C_i \geq 0$: Completion time slot for session $i$ (latest charging time slot)
# - $AP_{max,h}$: Maximum aggregate power during time period $h$
#
# ### Charging Station Specifications:
# - **Level 2 (L2) AC Charging Station**
# - **Continuous Power Range**: 1.2 kW ≤ P ≤ 7.0 kW
# - **Flexible Charging**: Charging can occur at any time within session window
# - **As Soon As Possible**: Complete charging at earliest opportunity while minimizing costs
#
# ---
#
# ## 3. Mathematical Model {#mathematical-model}
#
# ### 3.1 Objective Function
#
# Minimize total cost consisting of energy charges and demand charges:
#
# $\min \sum_{t=1}^{T} \left(\sum_{i=1}^{N} \sum_{j=1}^{M_i} \sum_{p \in P} p \cdot x_{i,j,t,p}\right) \cdot \Delta t \cdot \lambda(t) + \sum_{h \in H} AP_{max,h} \cdot DR_h$
#
# Where:
# - $P = \{1.2, 7.0\}$: Set of available power levels (kW)
# - $p$: Power level (1.2 kW or 7.0 kW)
# - $\Delta t$: Time step duration (0.25 hours)
# - $\lambda(t)$: Energy rate at time $t$ ($/kWh)
# - $DR_h$: Demand rate for period $h$ ($/kW)
# - $H$: Set of demand charge periods {peak, part-peak, anytime}
#
# ### 3.2 Constraints
#
# #### 3.2.1 Charging Block Scheduling
# Each charging block must be scheduled exactly once with exactly one power level:
#
# $\sum_{t=1}^{T} \sum_{p \in P} x_{i,j,t,p} = 1 \quad \forall i \in [1,N], \forall j \in [1,M_i]$
#
# #### 3.2.2 Time Window Constraints
# Charging blocks must be within session availability window:
#
# $x_{i,j,t,p} = 0 \quad \forall t \notin [t_i^a, t_i^d], \forall i, j, p$
#
# Where $t_i^a$ and $t_i^d$ are arrival and departure time slots for session $i$.
#
# #### 3.2.3 Charging Order Constraints (Option A)
# Maintain continuous charging order within each session:
#
# $\sum_{t=1}^{T} \sum_{p \in P} t \cdot x_{i,j,t,p} + 1 \leq \sum_{t=1}^{T} \sum_{p \in P} t \cdot x_{i,j+1,t,p} \quad \forall i, \forall j \in [1,M_i-1]$
#
# #### 3.2.4 Energy Requirement Constraints
# Total energy delivered must meet session requirements:
#
# $\sum_{j=1}^{M_i} \sum_{t=1}^{T} \sum_{p \in P} p \cdot x_{i,j,t,p} \cdot \Delta t = E_i \quad \forall i$
#
# Where $E_i$ is the energy requirement for session $i$ (kWh).
#
# #### 3.2.5 Demand Charge Constraints
# Track maximum demand for each time period:
#
# $AP_{max,h} \geq \sum_{i=1}^{N} \sum_{j=1}^{M_i} \sum_{p \in P} p \cdot x_{i,j,t,p} \quad \forall t \in T_h, \forall h \in H$
#
# Where $T_h$ is the set of time slots in period $h$.
#
# ### 3.3 Rate Structure (PG&E E-19)
#
# #### Summer Periods (May 1 - Oct 31):
# - **Peak**: 12:00 PM - 6:00 PM
#   - Energy: $0.14726/kWh
#   - Demand: $18.74/kW
# - **Part-Peak**: 8:30 AM-12:00 PM, 6:00 PM-9:30 PM
#   - Energy: $0.10714/kWh
#   - Demand: $5.23/kW
# - **Off-Peak**: All other times
#   - Energy: $0.08057/kWh
# - **Anytime Max Demand**: $17.33/kW
#
# #### Winter Periods (Nov 1 - Apr 30):
# - **Part-Peak**: 8:30 AM - 9:30 PM
#   - Energy: $0.10166/kWh
#   - Demand: $0.13/kW
# - **Off-Peak**: All other times
#   - Energy: $0.08717/kWh
# - **Anytime Max Demand**: $17.33/kW
#
# ---
#
# ## 4. Implementation {#implementation}
#
# Implement the optimization model step by step.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import pulp
from typing import List, Dict, Tuple
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
print("PuLP version:", pulp.__version__)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2586719
# Academic license - for non-commercial use only - expires 2025-11-18
# Set parameter Username
# Set parameter LicenseID to value 2586719
# Academic license - for non-commercial use only - expires 2025-11-18
# Set parameter Username
# Set parameter LicenseID to value 2586719
# Academic license - for non-commercial use only - expires 2025-11-18
# Set parameter Username
# Set parameter LicenseID to value 2586719
# Academic license - for non-commercial use only - expires 2025-11-18
# Set parameter Username
# Set parameter LicenseID to value 2586719
# Academic license - for non-commercial use only - expires 2025-11-18
# Set parameter Username
# Set parameter LicenseID to value 2586719
# Academic license - for non-commercial use only - expires 2025-11-18
# Libraries imported successfully!
# PuLP version: 3.0.2

# %%
# EVChargingOptimizer Class Definition
class EVChargingOptimizer:
    """
    Mixed Integer Linear Programming optimizer for EV charging sessions
    to minimize energy costs using 15-minute time steps.
    """
    
    def __init__(self, start_date: str = "2017-08-01"):
        """
        Initialize the optimizer with time parameters and rate structure.
        
        Args:
            start_date: Start date for optimization (YYYY-MM-DD format)
        """
        self.start_date = datetime.strptime(start_date, "%Y-%m-%d")
        self.time_step_minutes = 15
        self.optimization_horizon_hours = 32  # Until (day+1) 08:00
        self.total_time_slots = int(self.optimization_horizon_hours * 60 / self.time_step_minutes)
        
        # L2 Charging Station Continuous Power Range
        self.min_power = 1.2  # kW: Minimum power level
        self.max_power = 7.0  # kW: Maximum power level
        
        # Create time slots from start_date 00:00 to next day 08:00
        self.time_slots = []
        current_time = self.start_date
        for i in range(self.total_time_slots):
            self.time_slots.append(current_time)
            current_time += timedelta(minutes=self.time_step_minutes)
        
        # Define rate structure based on PG&E E-19
        self.setup_rate_structure()
        
        print(f"Optimizer initialized for {start_date}")
        print(f"L2 Charging Station Power Range: {self.min_power} - {self.max_power} kW (Continuous)")
        print(f"Optimization period: {self.total_time_slots} time slots (15-min each)")
        print(f"Rate period: {'Summer' if self.is_summer else 'Winter'}")
        
    def setup_rate_structure(self):
        """Setup energy and demand charge rates based on PG&E E-19 schedule."""
        # Determine if summer or winter period
        month = self.start_date.month
        is_summer = month >= 5 and month <= 10
        
        if is_summer:
            # Summer rates (May 1 - Oct 31)
            self.energy_rates = {
                'peak': 0.14726,      # 12:00 PM - 6:00 PM
                'part_peak': 0.10714, # 8:30 AM-12:00 PM, 6:00 PM-9:30 PM
                'off_peak': 0.08057   # All other times
            }
            self.demand_rates = {
                'peak': 18.74,        # 12:00 PM - 6:00 PM
                'part_peak': 5.23,    # 8:30 AM-12:00 PM, 6:00 PM-9:30 PM
                'anytime': 17.33      # Any time
            }
        else:
            # Winter rates (Nov 1 - Apr 30)
            self.energy_rates = {
                'part_peak': 0.10166, # 8:30 AM - 9:30 PM
                'off_peak': 0.08717   # All other times
            }
            self.demand_rates = {
                'part_peak': 0.13,    # 8:30 AM - 9:30 PM
                'anytime': 17.33      # Any time
            }
        
        self.is_summer = is_summer
        
    def get_time_period(self, time_slot: datetime) -> str:
        """Determine the time-of-use period for a given time slot."""
        hour = time_slot.hour
        minute = time_slot.minute
        time_decimal = hour + minute / 60.0
        
        if self.is_summer:
            # Summer periods
            if 12.0 <= time_decimal < 18.0:  # 12:00 PM - 6:00 PM
                return 'peak'
            elif (8.5 <= time_decimal < 12.0) or (18.0 <= time_decimal < 21.5):
                return 'part_peak'
            else:
                return 'off_peak'
        else:
            # Winter periods
            if 8.5 <= time_decimal < 21.5:  # 8:30 AM - 9:30 PM
                return 'part_peak'
            else:
                return 'off_peak'

# %%
def load_charging_sessions(self, data: List[Dict]) -> pd.DataFrame:
    """
    Load and process charging session data for flexible L2 charging.
    
    Args:
        data: List of dictionaries with keys: 'event_id', 'start_time', 'end_time', 'energy_kwh'
    
    Returns:
        DataFrame with processed charging session data
    """
    sessions = []
    optimization_end_time = self.start_date + timedelta(hours=self.optimization_horizon_hours)
    
    for session in data:
        # Convert string times to datetime if needed
        if isinstance(session['start_time'], str):
            start_time = datetime.strptime(session['start_time'], "%Y-%m-%d %H:%M:%S")
        else:
            start_time = session['start_time']
            
        if isinstance(session['end_time'], str):
            end_time = datetime.strptime(session['end_time'], "%Y-%m-%d %H:%M:%S")
        else:
            end_time = session['end_time']
        
        # Skip sessions that don't overlap with optimization period
        if end_time <= self.start_date or start_time >= optimization_end_time:
            continue
            
        # Skip sessions with zero or negative energy
        if session['energy_charged_kWh'] <= 0:
            continue
        
        # Constrain session times to optimization window
        constrained_start = max(start_time, self.start_date)
        constrained_end = min(end_time, optimization_end_time)
        
        # Calculate session duration
        duration_hours = (end_time - start_time).total_seconds() / 3600
        session_duration_slots = int((constrained_end - constrained_start).total_seconds() / (self.time_step_minutes * 60))
        
        # Calculate minimum time needed for charging
        time_step_hours = self.time_step_minutes / 60
        min_time_needed_hours = session['energy_charged_kWh'] / self.max_power  # Using maximum power
        min_slots_needed = int(np.ceil(min_time_needed_hours / time_step_hours))
        
        # Check if session can be satisfied within time window
        if min_slots_needed > session_duration_slots:
            print(f"Warning: Session {session['event_id']} cannot be satisfied within time window")
            continue
        
        # Determine time slot indices
        start_slot = max(0, int((constrained_start - self.start_date).total_seconds() / (self.time_step_minutes * 60)))
        end_slot = min(self.total_time_slots - 1, 
                      int((constrained_end - self.start_date).total_seconds() / (self.time_step_minutes * 60)))
        
        # Skip sessions that are too short
        if end_slot <= start_slot:
            continue
        
        sessions.append({
            'event_id': session['Plug In Event Id'],
            'start_time': start_time,
            'end_time': end_time,
            'constrained_start': constrained_start,
            'constrained_end': constrained_end,
            'energy_kwh': session['energy_charged_kWh'],
            'start_slot': start_slot,
            'end_slot': end_slot,
            'duration_hours': duration_hours,
            'min_slots_needed': min_slots_needed,
            'session_duration_slots': session_duration_slots,
            'min_completion_time': start_slot + min_slots_needed - 1,
            'latest_start_slot': end_slot - min_slots_needed + 1
        })
    
    return pd.DataFrame(sessions)

# Add method to the class
EVChargingOptimizer.load_charging_sessions = load_charging_sessions

print("Add Data loading functions!")
# Out:
# Add Data loading functions!

# %%
# MILP Model Creation with Smart Charging Management without Early Completion Incentive
def create_milp_model(self, sessions_df: pd.DataFrame) -> Tuple[pulp.LpProblem, Dict]:
    """
    Create the Mixed Integer Linear Programming model for flexible charging optimization
    with continuous L2 power levels and no early completion incentive.

    Args:
        sessions_df: DataFrame with charging session data
    
    Returns:
        Tuple of (optimization model, decision variables dictionary)
    """
    print("Creating MILP model with flexible charging and no early completion incentive...")
    print(f"Sessions to optimize: {len(sessions_df)}")
    print(f"Time slots: {self.total_time_slots}")
    print(f"Power range: {self.min_power} - {self.max_power} kW (Continuous)")
    
    # Create the optimization model
    model = pulp.LpProblem("EV_Charging_Flexible_Optimization", pulp.LpMinimize)
    
    # Decision variables
    charge_variables = {}    # x[session_id][time_slot] - binary charging indicator
    power_variables = {}     # P[session_id][time_slot] - continuous power level
    # completion_variables = {} # C[session_id] - completion time slot
    
    total_binary_vars = 0
    total_continuous_vars = 0
    
    for _, session in sessions_df.iterrows():
        session_id = session['event_id']
        charge_variables[session_id] = {}
        power_variables[session_id] = {}
        
        # Completion time variable for this session
        # completion_variables[session_id] = pulp.LpVariable(
        #     f"C_{session_id}", lowBound=0, cat='Continuous'
        # )
        total_continuous_vars += 1
        
        for t in range(self.total_time_slots):
            # Binary charging indicator
            charge_var_name = f"x_{session_id}_{t}"
            charge_variables[session_id][t] = pulp.LpVariable(charge_var_name, cat='Binary')
            total_binary_vars += 1
            
            # Continuous power variable
            power_var_name = f"P_{session_id}_{t}"
            power_variables[session_id][t] = pulp.LpVariable(
                power_var_name, lowBound=0, upBound=self.max_power, cat='Continuous'
            )
            total_continuous_vars += 1

    print(f"Created {total_binary_vars} binary variables and {total_continuous_vars} continuous variables")
    
    # Continuous variables for demand charges
    demand_vars = {}
    if self.is_summer:
        demand_vars['peak'] = pulp.LpVariable("max_peak_demand", lowBound=0, cat='Continuous')
        demand_vars['part_peak'] = pulp.LpVariable("max_part_peak_demand", lowBound=0, cat='Continuous')
    else:
        demand_vars['part_peak'] = pulp.LpVariable("max_part_peak_demand", lowBound=0, cat='Continuous')
    demand_vars['anytime'] = pulp.LpVariable("max_anytime_demand", lowBound=0, cat='Continuous')
    
    # Objective function: Minimize total cost + completion time penalty
    total_cost = 0
    # completion_penalty_weight = 0.01  # Small weight to encourage early completion
    
    # Energy cost component
    for t, time_slot in enumerate(self.time_slots):
        period = self.get_time_period(time_slot)
        energy_rate = self.energy_rates[period]
        
        # Total power at time slot t
        total_power_t = 0
        for _, session in sessions_df.iterrows():
            session_id = session['event_id']
            total_power_t += power_variables[session_id][t]
        
        # Energy cost for this time slot (power * time_step_hours * rate)
        time_step_hours = self.time_step_minutes / 60
        total_cost += total_power_t * time_step_hours * energy_rate
    
    # Demand cost component
    for period, rate in self.demand_rates.items():
        if period in demand_vars:
            total_cost += demand_vars[period] * rate
    
    # # Completion time penalty (encourage early completion)
    # for _, session in sessions_df.iterrows():
    #     session_id = session['event_id']
    #     total_cost += completion_penalty_weight * completion_variables[session_id]
    
    model += total_cost, "Total_Cost_Plus_Completion_Penalty"
    
    print("Adding constraints...")
    
    # Constraints
    constraint_count = 0
    
    # 1. Power level bounds: P[i,t] = 0 when x[i,t] = 0, 
    #    and min_power <= P[i,t] <= max_power when x[i,t] = 1
    for _, session in sessions_df.iterrows():
        session_id = session['event_id']
        for t in range(self.total_time_slots):
            # Lower bound: P[i,t] >= min_power * x[i,t]
            model += power_variables[session_id][t] >= \
                    self.min_power * charge_variables[session_id][t], \
                    f"Power_Lower_{session_id}_{t}"
            constraint_count += 1
            
            # Upper bound: P[i,t] <= max_power * x[i,t]
            model += power_variables[session_id][t] <= \
                    self.max_power * charge_variables[session_id][t], \
                    f"Power_Upper_{session_id}_{t}"
            constraint_count += 1
    
    # 2. Charging must be within session time window
    for _, session in sessions_df.iterrows():
        session_id = session['event_id']
        start_slot = session['start_slot']
        end_slot = session['end_slot']
        
        for t in range(self.total_time_slots):
            if t < start_slot or t > end_slot:
                model += charge_variables[session_id][t] == 0, \
                       f"Time_Window_{session_id}_{t}"
                constraint_count += 1
    
    # 3. Energy requirement constraints
    time_step_hours = self.time_step_minutes / 60
    for _, session in sessions_df.iterrows():
        session_id = session['event_id']
        required_energy = session['energy_kwh']
        
        total_energy = pulp.lpSum([power_variables[session_id][t] * time_step_hours
                                 for t in range(self.total_time_slots)])
        
        model += total_energy == required_energy, f"Energy_Requirement_{session_id}"
        constraint_count += 1
    
    # # 4. Completion time tracking constraints
    # for _, session in sessions_df.iterrows():
    #     session_id = session['event_id']
    #     for t in range(self.total_time_slots):
    #         # If charging at time t, completion time must be at least t
    #         model += completion_variables[session_id] >= t * charge_variables[session_id][t], \
    #                f"Completion_Time_{session_id}_{t}"
    #         constraint_count += 1
    
    # 5. Demand charge constraints
    for t, time_slot in enumerate(self.time_slots):
        period = self.get_time_period(time_slot)
        
        # Calculate total demand at time slot t
        total_demand_t = 0
        for _, session in sessions_df.iterrows():
            session_id = session['event_id']
            total_demand_t += power_variables[session_id][t]
        
        # Update maximum demand variables
        if period in demand_vars:
            model += demand_vars[period] >= total_demand_t, \
                   f"Max_Demand_{period}_{t}"
            constraint_count += 1
        
        # Anytime maximum demand
        model += demand_vars['anytime'] >= total_demand_t, \
               f"Max_Anytime_Demand_{t}"
        constraint_count += 1
    
    print(f"Added {constraint_count} constraints")
    
    return model, charge_variables, demand_vars, power_variables

# Add method to the class
EVChargingOptimizer.create_milp_model = create_milp_model

print("MILP model creation function!")
# Out:
# MILP model creation function!

# %% [markdown]
# ## 5. Real Data Analysis {#real-data-analysis}
#
# Load and analyze the real charging session data from August 1, 2017.

# %%
# Initialize the optimizer
optimizer = EVChargingOptimizer(start_date="2017-08-01")

# Load actual charging session data
print("Loading real charging session data...")

# Load the JSON data from the file or any other source
import json
with open(f'data/chapter5/extracted_data_{'2017-08-01'}.json', 'r') as f:
    actual_data = json.load(f)
sessions_df = optimizer.load_charging_sessions(actual_data)

print(f"\nDataset Summary:")
print(f"- Total sessions loaded: {len(actual_data)}")
print(f"- Sessions for optimization: {len(sessions_df)}")
print(f"- Total energy requirement: {sessions_df['energy_kwh'].sum():.1f} kWh")
print(f"- Average session energy: {sessions_df['energy_kwh'].mean():.1f} kWh")
print(f"- Average session duration: {sessions_df['duration_hours'].mean():.1f} hours")

# Display sample sessions
print(f"\nSample charging sessions:")
display_cols = ['event_id', 'start_time', 'end_time', 'energy_kwh', 
                'min_slots_needed', 'session_duration_slots', 'min_completion_time']
display_df = sessions_df[display_cols].head()
print(display_df.to_string())

print(f"\nFlexible L2 Charging Analysis:")
time_step_hours = 0.25  # 15 minutes
energy_per_slot_min = 1.2 * time_step_hours  # kWh per 15-min slot at 1.2 kW
energy_per_slot_max = 7.0 * time_step_hours  # kWh per 15-min slot at 7.0 kW

print(f"Energy per 15-min time slot range:")
print(f"  Minimum power (1.2 kW): {energy_per_slot_min:.2f} kWh")
print(f"  Maximum power (7.0 kW): {energy_per_slot_max:.2f} kWh")
print(f"  Flexible charging: Can charge at any time within session window")
print(f"  Early completion: Optimizer incentivized to complete ASAP")

# Check feasibility for each session
print(f"\nSession Feasibility & Completion Analysis:")
for _, session in sessions_df.head().iterrows():
    earliest_completion = session['start_slot'] + session['min_slots_needed'] - 1
    latest_start = session['end_slot'] - session['min_slots_needed'] + 1
    
    print(f"Session {session['event_id']}:")
    print(f"  Energy needed: {session['energy_kwh']:.2f} kWh")
    print(f"  Min slots needed: {session['min_slots_needed']} (using 7.0 kW)")
    print(f"  Available slots: {session['session_duration_slots']}")
    print(f"  Earliest completion: Slot {earliest_completion}")
    print(f"  Latest start allowed: Slot {latest_start}")
    print(f"  Flexibility: {session['session_duration_slots'] - session['min_slots_needed']} extra slots")
    print(f"  Feasible: {'✓' if session['min_slots_needed'] <= session['session_duration_slots'] else '✗'}")
# Out:
# Optimizer initialized for 2017-08-01
# L2 Charging Station Power Range: 1.2 - 7.0 kW (Continuous)
# Optimization period: 128 time slots (15-min each)
# Rate period: Summer
# Loading real charging session data...
#
# Dataset Summary:
# - Total sessions loaded: 30
# - Sessions for optimization: 29
# - Total energy requirement: 271.4 kWh
# - Average session energy: 9.4 kWh
# - Average session duration: 12.0 hours
#
# Sample charging sessions:
#    event_id          start_time            end_time  energy_kwh  min_slots_needed  session_duration_slots  min_completion_time
# 0  77344924 2017-08-01 19:15:00 2017-08-02 01:00:00    7.230203                 5                      23                   81
# 1  77340858 2017-08-01 18:15:00 2017-08-02 08:30:00   12.326301                 8                      55                   80
# 2  77339080 2017-08-01 18:00:00 2017-08-02 07:15:00    8.411539                 5                      53                   76
# 3  77336462 2017-08-01 17:30:00 2017-08-01 17:45:00    0.885824                 1                       1                   70
# 4  77335566 2017-08-01 17:15:00 2017-08-02 09:15:00    9.525474                 6                      59                   74
#
# Flexible L2 Charging Analysis:
# Energy per 15-min time slot range:
#   Minimum power (1.2 kW): 0.30 kWh
#   Maximum power (7.0 kW): 1.75 kWh
#   Flexible charging: Can charge at any time within session window
#   Early completion: Optimizer incentivized to complete ASAP
#
# Session Feasibility & Completion Analysis:
# Session 77344924:
#   Energy needed: 7.23 kWh
#   Min slots needed: 5 (using 7.0 kW)
#   Available slots: 23
#   Earliest completion: Slot 81
#   Latest start allowed: Slot 96
#   Flexibility: 18 extra slots
#   Feasible: ✓
# Session 77340858:
#   Energy needed: 12.33 kWh
#   Min slots needed: 8 (using 7.0 kW)
#   Available slots: 55
#   Earliest completion: Slot 80
#   Latest start allowed: Slot 120
#   Flexibility: 47 extra slots
#   Feasible: ✓
# Session 77339080:
#   Energy needed: 8.41 kWh
#   Min slots needed: 5 (using 7.0 kW)
#   Available slots: 53
#   Earliest completion: Slot 76
#   Latest start allowed: Slot 121
#   Flexibility: 48 extra slots
#   Feasible: ✓
# Session 77336462:
#   Energy needed: 0.89 kWh
#   Min slots needed: 1 (using 7.0 kW)
#   Available slots: 1
#   Earliest completion: Slot 70
#   Latest start allowed: Slot 71
#   Flexibility: 0 extra slots
#   Feasible: ✓
# Session 77335566:
#   Energy needed: 9.53 kWh
#   Min slots needed: 6 (using 7.0 kW)
#   Available slots: 59
#   Earliest completion: Slot 74
#   Latest start allowed: Slot 122
#   Flexibility: 53 extra slots
#   Feasible: ✓

# %%
# Visualize Data Characteristics
# Set up plotting style
plt.style.use('default')
sns.set_palette("husl")

# Create subplots for data analysis
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('EV Charging Session Analysis - August 1, 2017', fontsize=16)

# 1. Energy distribution
axes[0,0].hist(sessions_df['energy_kwh'], bins=15, alpha=0.7, edgecolor='black')
axes[0,0].set_xlabel('Energy Required (kWh)')
axes[0,0].set_ylabel('Number of Sessions')
axes[0,0].set_title('Distribution of Energy Requirements')
axes[0,0].grid(True, alpha=0.3)

# 2. Power distribution
axes[0,1].hist(sessions_df['energy_kwh']/sessions_df['duration_hours'], bins=15, alpha=0.7, color='orange', edgecolor='black')
axes[0,1].set_xlabel('Average Power (kW)')
axes[0,1].set_ylabel('Number of Sessions')
axes[0,1].set_title('Distribution of Charging Power')
axes[0,1].grid(True, alpha=0.3)

# 3. Session duration
axes[1,0].hist(sessions_df['duration_hours'], bins=15, alpha=0.7, color='green', edgecolor='black')
axes[1,0].set_xlabel('Session Duration (hours)')
axes[1,0].set_ylabel('Number of Sessions')
axes[1,0].set_title('Distribution of Session Durations')
axes[1,0].grid(True, alpha=0.3)

# 4. Start time distribution
start_hours = [t.hour for t in sessions_df['start_time']]
axes[1,1].hist(start_hours, bins=24, alpha=0.7, color='red', edgecolor='black')
axes[1,1].set_xlabel('Start Hour of Day')
axes[1,1].set_ylabel('Number of Sessions')
axes[1,1].set_title('Distribution of Session Start Times')
axes[1,1].set_xticks(range(0, 24, 4))
axes[1,1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Rate Structure Visualization
# Visualize the time-of-use rate structure
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 8))

# Create hourly rate schedule
hours = np.arange(24)
energy_rates_hourly = []
demand_rates_hourly = []

for hour in hours:
    time_slot = optimizer.start_date.replace(hour=hour, minute=0)
    period = optimizer.get_time_period(time_slot)
    energy_rates_hourly.append(optimizer.energy_rates[period])
    demand_rates_hourly.append(optimizer.demand_rates.get(period, 0))

# Plot energy rates
colors = ['red' if r == max(optimizer.energy_rates.values()) else 
          'orange' if r == sorted(optimizer.energy_rates.values())[-2] else 'green' 
          for r in energy_rates_hourly]

ax1.bar(hours, energy_rates_hourly, color=colors, alpha=0.7, edgecolor='black')
ax1.set_xlabel('Hour of Day')
ax1.set_ylabel('Energy Rate ($/kWh)')
ax1.set_title('PG&E E-19 Energy Rates by Hour (Summer 2017)')
ax1.set_xticks(range(0, 24, 2))
ax1.grid(True, alpha=0.3)

# Add period labels
for i, (hour, rate) in enumerate(zip(hours, energy_rates_hourly)):
    time_slot = optimizer.start_date.replace(hour=hour, minute=0)
    period = optimizer.get_time_period(time_slot).replace('_', '-')
    if i % 3 == 0:  # Show every 3rd label to avoid crowding
        ax1.text(hour, rate + 0.002, period, ha='center', va='bottom', fontsize=8)

# Plot demand rates
colors_demand = ['red' if r == max([r for r in demand_rates_hourly if r > 0]) else 
                'orange' if r > 0 and r != max([r for r in demand_rates_hourly if r > 0]) else 'green' 
                for r in demand_rates_hourly]

ax2.bar(hours, demand_rates_hourly, color=colors_demand, alpha=0.7, edgecolor='black')
ax2.set_xlabel('Hour of Day')
ax2.set_ylabel('Demand Rate ($/kW)')
ax2.set_title('PG&E E-19 Demand Rates by Hour (Summer 2017)')
ax2.set_xticks(range(0, 24, 2))
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("Rate Structure Summary:")
print("Energy Rates:", optimizer.energy_rates)
print("Demand Rates:", optimizer.demand_rates)
# Out:
# Rate Structure Summary:
# Energy Rates: {'peak': 0.14726, 'part_peak': 0.10714, 'off_peak': 0.08057}
# Demand Rates: {'peak': 18.74, 'part_peak': 5.23, 'anytime': 17.33}

# %% [markdown]
# ## 6. Results and Discussion {#results-and-discussion}
#
# Solve the optimization problem and analyze the results.
#
# **Note**: Due to the computational complexity of this MILP problem (28 sessions × ~60 charging blocks × 128 time slots),
# we'll solve with a subset of sessions for demonstration purposes. In practice, we can use:
# - Commercial solvers (Gurobi, CPLEX) for better performance
# - Rolling horizon optimization for larger datasets
# - Heuristic algorithms for real-time applications

# %%
# Solve Optimization with Flexible Charging
def solve_optimization_demo(optimizer, sessions_df, max_sessions=3):
    """
    Solve optimization for smart charging with early completion incentive.
    """
    print(f"Solving optimization for first {max_sessions} sessions...")
    
    # Select subset for demonstration
    demo_sessions = sessions_df.head(max_sessions).copy()
    
    print(f"Demo dataset:")
    print(f"- Sessions: {len(demo_sessions)}")
    print(f"- Total energy: {demo_sessions['energy_kwh'].sum():.1f} kWh")
    print(f"- Min slots needed: {demo_sessions['min_slots_needed'].sum()}")
    print(f"- Power range: {optimizer.min_power} - {optimizer.max_power} kW (Continuous)")
    print(f"- Charging strategy: Flexible timing with early completion incentive")
    
    # Create and solve model
    model, charge_vars, demand_vars, power_vars = optimizer.create_milp_model(demo_sessions)
    
    print("\nSolving MILP model...")
    solver = pulp.PULP_CBC_CMD(msg=1, timeLimit=180)  # 3 minute time limit for demo
    model.solve(solver)
    
    # Extract results
    results = {
        'status': pulp.LpStatus[model.status],
        'objective_value': pulp.value(model.objective) if model.status == pulp.LpStatusOptimal else None,
        'charging_schedule': {},
        'demand_charges': {},
        'total_demand_by_period': {}
    }
    
    if model.status == pulp.LpStatusOptimal:
        print(f"Optimization successful!")
        print(f"Optimal objective: ${results['objective_value']:.2f}")
        
        # Extract charging schedule with flexible timing
        for _, session in demo_sessions.iterrows():
            session_id = session['event_id']
            results['charging_schedule'][session_id] = []
            
            for t in range(optimizer.total_time_slots):
                if pulp.value(charge_vars[session_id][t]) == 1:
                    power_level = pulp.value(power_vars[session_id][t])
                    results['charging_schedule'][session_id].append({
                        'time_slot': t,
                        'time': optimizer.time_slots[t],
                        'power_kw': power_level,
                        'energy_kwh': power_level * (optimizer.time_step_minutes / 60)
                    })
            
            # # Extract completion time
            # results['completion_times'][session_id] = pulp.value(completion_vars[session_id])
        
        # Extract demand charges
        for period, var in demand_vars.items():
            results['demand_charges'][period] = pulp.value(var)
            results['total_demand_by_period'][period] = pulp.value(var) * optimizer.demand_rates[period]
    
    else:
        print(f"Optimization failed with status: {results['status']}")
    
    return results, demo_sessions

# Run the optimization
results, demo_sessions = solve_optimization_demo(optimizer, sessions_df, max_sessions=3)
# Out:
# Solving optimization for first 3 sessions...
# Demo dataset:
# - Sessions: 3
# - Total energy: 28.0 kWh
# - Min slots needed: 18
# - Power range: 1.2 - 7.0 kW (Continuous)
# - Charging strategy: Flexible timing with early completion incentive
# Creating MILP model with flexible charging and no early completion incentive...
# Sessions to optimize: 3
# Time slots: 128
# Power range: 1.2 - 7.0 kW (Continuous)
# Created 384 binary variables and 387 continuous variables
# Adding constraints...
# Added 1202 constraints
#
# Solving MILP model...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ryin/myenv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/fq/6vcnqd4d3nlcwtdmsgb31hx40000gn/T/41d712e57da44a5192ae0eb468e3879d-pulp.mps -sec 180 -timeMode elapsed -branch -printingOptions all -solution /var/folders/fq/6vcnqd4d3nlcwtdmsgb31hx40000gn/T/41d712e57da44a5192ae0eb468e3879d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1207 COLUMNS
# At line 5254 RHS
# At line 6457 BOUNDS
# At line 7226 ENDATA
# Problem MODEL has 1202 rows, 771 columns and 2891 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 180
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 47.5077 - 0.00 seconds
# Cgl0002I 251 variables fixed
# Cgl0004I processed model has 339 rows, 268 columns (133 integer (133 of which binary)) and 904 elements
# Cbc0038I Initial state - 58 integers unsatisfied sum - 15.9817
# Cbc0038I Pass   1: suminf.    0.36855 (3) obj. 318.288 iterations 120
# Cbc0038I Pass   2: suminf.    0.17515 (2) obj. 318.288 iterations 16
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 318.295 iterations 17
# Cbc0038I Solution found of 318.295
# Cbc0038I Relaxing continuous gives 159.62
# Cbc0038I Before mini branch and bound, 64 integers at bound fixed and 64 continuous
# Cbc0038I Full problem 339 rows 268 columns, reduced to 211 rows 140 columns - 1 fixed gives 209, 139 - still too large
# Cbc0038I Full problem 339 rows 268 columns, reduced to 209 rows 139 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of 148.409
# Cbc0038I Pass   4: suminf.    2.25553 (19) obj. 148.409 iterations 17
# Cbc0038I Pass   5: suminf.    0.61748 (2) obj. 148.409 iterations 54
# Cbc0038I Solution found of 148.409
# Cbc0038I Relaxing continuous gives 139.516
# Cbc0038I Before mini branch and bound, 64 integers at bound fixed and 64 continuous
# Cbc0038I Full problem 339 rows 268 columns, reduced to 211 rows 140 columns - 16 fixed gives 179, 124 - still too large
# Cbc0038I Full problem 339 rows 268 columns, reduced to 179 rows 124 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of 121.115
# Cbc0038I Pass   6: suminf.    5.91929 (23) obj. 121.115 iterations 10
# Cbc0038I Pass   7: suminf.    0.95052 (3) obj. 121.115 iterations 31
# Cbc0038I Solution found of 121.115
# Cbc0038I Relaxing continuous gives 113.065
# Cbc0038I Before mini branch and bound, 62 integers at bound fixed and 62 continuous
# Cbc0038I Full problem 339 rows 268 columns, reduced to 215 rows 144 columns - 16 fixed gives 183, 128 - still too large
# Cbc0038I Full problem 339 rows 268 columns, reduced to 183 rows 128 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 113.065
# Cbc0038I Round again with cutoff of 93.3975
# Cbc0038I Pass   8: suminf.   12.03149 (30) obj. 93.3975 iterations 8
# Cbc0038I Pass   9: suminf.    1.00661 (4) obj. 93.3975 iterations 41
# Cbc0038I Pass  10: suminf.    0.00000 (0) obj. 93.3975 iterations 45
# Cbc0038I Solution found of 93.3975
# Cbc0038I Relaxing continuous gives 89.5756
# Cbc0038I Before mini branch and bound, 60 integers at bound fixed and 60 continuous
# Cbc0038I Full problem 339 rows 268 columns, reduced to 219 rows 148 columns - 16 fixed gives 187, 132 - still too large
# Cbc0038I Full problem 339 rows 268 columns, reduced to 187 rows 132 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 89.5756
# Cbc0038I Round again with cutoff of 76.9552
# Cbc0038I Pass  11: suminf.   15.98174 (36) obj. 76.9552 iterations 7
# Cbc0038I Pass  12: suminf.    2.29594 (7) obj. 76.9552 iterations 46
# Cbc0038I Pass  13: suminf.    0.14216 (2) obj. 76.9552 iterations 49
# Cbc0038I Pass  14: suminf.    0.00000 (0) obj. 76.9552 iterations 36
# Cbc0038I Solution found of 76.9552
# Cbc0038I Relaxing continuous gives 75.2471
# Cbc0038I Before mini branch and bound, 56 integers at bound fixed and 56 continuous
# Cbc0038I Full problem 339 rows 268 columns, reduced to 227 rows 156 columns - 16 fixed gives 195, 140 - still too large
# Cbc0038I Full problem 339 rows 268 columns, reduced to 195 rows 140 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 75.2471
# Cbc0038I Round again with cutoff of 64.1513
# Cbc0038I Pass  15: suminf.   15.98174 (43) obj. 64.1513 iterations 12
# Cbc0038I Pass  16: suminf.    4.78522 (19) obj. 64.1513 iterations 87
# Cbc0038I Pass  17: suminf.    0.22806 (2) obj. 64.1513 iterations 65
# Cbc0038I Pass  18: suminf.    0.00437 (1) obj. 64.1513 iterations 46
# Cbc0038I Pass  19: suminf.    0.00000 (0) obj. 64.1513 iterations 20
# Cbc0038I Solution found of 64.1513
# Cbc0038I Relaxing continuous gives 63.0995
# Cbc0038I Before mini branch and bound, 51 integers at bound fixed and 51 continuous
# Cbc0038I Full problem 339 rows 268 columns, reduced to 237 rows 166 columns - 16 fixed gives 205, 150 - still too large
# Cbc0038I Full problem 339 rows 268 columns, reduced to 205 rows 150 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 63.0995
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 63.0995 - took 0.04 seconds
# Cbc0012I Integer solution of 63.099521 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0012I Integer solution of 60.562174 found by DiveCoefficient after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 189 rows 118 columns - 4 fixed gives 181, 114 - still too large
# Cbc0038I Full problem 339 rows 268 columns, reduced to 181 rows 114 columns - too large
# Cbc0012I Integer solution of 49.023999 found by DiveCoefficient after 726 iterations and 0 nodes (0.17 seconds)
# Cbc0031I 67 added rows had average density of 30.074627
# Cbc0013I At root node, 67 cuts changed objective from 47.507667 to 47.507667 in 21 passes
# Cbc0014I Cut generator 0 (Probing) - 87 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 195 row cuts average 159.5 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 3 row cuts average 88.7 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 3 row cuts average 38.7 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 97 row cuts average 60.4 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 49.023999 best solution, best possible 47.507667 (0.18 seconds)
# Cbc0012I Integer solution of 48.179841 found by DiveCoefficient after 729 iterations and 1 nodes (0.18 seconds)
# Cbc0012I Integer solution of 47.875491 found by DiveCoefficient after 829 iterations and 10 nodes (0.20 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 99 rows 79 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 103 rows 83 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 109 rows 87 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 99 rows 79 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 111 rows 89 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 105 rows 83 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 115 rows 90 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 95 rows 75 columns
# Cbc0010I After 1000 nodes, 375 on tree, 47.875491 best solution, best possible 47.507667 (0.73 seconds)
# Cbc0016I Integer solution of 47.683137 found by strong branching after 14360 iterations and 1083 nodes (0.79 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 151 rows 118 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 143 rows 112 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 153 rows 119 columns
# Cbc0010I After 2000 nodes, 856 on tree, 47.683137 best solution, best possible 47.507667 (1.14 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 151 rows 117 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 153 rows 119 columns
# Cbc0010I After 3000 nodes, 1317 on tree, 47.683137 best solution, best possible 47.507667 (1.52 seconds)
# Cbc0010I After 4000 nodes, 1728 on tree, 47.683137 best solution, best possible 47.507667 (1.84 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 161 rows 126 columns
# Cbc0038I Full problem 339 rows 268 columns, reduced to 159 rows 124 columns
# Cbc0010I After 5000 nodes, 2195 on tree, 47.683137 best solution, best possible 47.507667 (2.18 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 127 rows 99 columns
# Cbc0010I After 6000 nodes, 2231 on tree, 47.683137 best solution, best possible 47.507667 (2.59 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 137 rows 106 columns
# Cbc0010I After 7000 nodes, 2229 on tree, 47.683137 best solution, best possible 47.507667 (2.99 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 123 rows 96 columns
# Cbc0010I After 8000 nodes, 2227 on tree, 47.683137 best solution, best possible 47.507667 (3.43 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 135 rows 105 columns
# Cbc0010I After 9000 nodes, 2227 on tree, 47.683137 best solution, best possible 47.507667 (3.89 seconds)
# Cbc0010I After 10000 nodes, 2210 on tree, 47.683137 best solution, best possible 47.507667 (4.33 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 107 rows 85 columns
# Cbc0010I After 11000 nodes, 2213 on tree, 47.683137 best solution, best possible 47.507667 (4.74 seconds)
# Cbc0010I After 12000 nodes, 2643 on tree, 47.683137 best solution, best possible 47.507667 (5.09 seconds)
# Cbc0010I After 13000 nodes, 3148 on tree, 47.683137 best solution, best possible 47.507667 (5.43 seconds)
# Cbc0010I After 14000 nodes, 3171 on tree, 47.683137 best solution, best possible 47.507667 (5.72 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 145 rows 113 columns
# Cbc0010I After 15000 nodes, 3597 on tree, 47.683137 best solution, best possible 47.507667 (6.05 seconds)
# Cbc0010I After 16000 nodes, 3953 on tree, 47.683137 best solution, best possible 47.507667 (6.36 seconds)
# Cbc0010I After 17000 nodes, 4236 on tree, 47.683137 best solution, best possible 47.507667 (6.71 seconds)
# Cbc0010I After 18000 nodes, 4222 on tree, 47.683137 best solution, best possible 47.507667 (7.10 seconds)
# Cbc0010I After 19000 nodes, 4572 on tree, 47.683137 best solution, best possible 47.507667 (7.43 seconds)
# Cbc0010I After 20000 nodes, 4867 on tree, 47.683137 best solution, best possible 47.507667 (7.77 seconds)
# Cbc0010I After 21000 nodes, 5208 on tree, 47.683137 best solution, best possible 47.507667 (8.16 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 147 rows 115 columns
# Cbc0010I After 22000 nodes, 5220 on tree, 47.683137 best solution, best possible 47.507667 (8.55 seconds)
# Cbc0010I After 23000 nodes, 5492 on tree, 47.683137 best solution, best possible 47.507667 (9.05 seconds)
# Cbc0010I After 24000 nodes, 5945 on tree, 47.683137 best solution, best possible 47.507667 (9.41 seconds)
# Cbc0010I After 25000 nodes, 6342 on tree, 47.683137 best solution, best possible 47.507667 (9.78 seconds)
# Cbc0010I After 26000 nodes, 6370 on tree, 47.683137 best solution, best possible 47.507667 (10.13 seconds)
# Cbc0010I After 27000 nodes, 6731 on tree, 47.683137 best solution, best possible 47.507667 (10.48 seconds)
# Cbc0010I After 28000 nodes, 7264 on tree, 47.683137 best solution, best possible 47.507667 (10.88 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 169 rows 131 columns
# Cbc0010I After 29000 nodes, 7712 on tree, 47.683137 best solution, best possible 47.507667 (11.28 seconds)
# Cbc0010I After 30000 nodes, 7739 on tree, 47.683137 best solution, best possible 47.507667 (11.54 seconds)
# Cbc0010I After 31000 nodes, 8087 on tree, 47.683137 best solution, best possible 47.507667 (11.88 seconds)
# Cbc0010I After 32000 nodes, 8314 on tree, 47.683137 best solution, best possible 47.507667 (12.19 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 167 rows 129 columns
# Cbc0010I After 33000 nodes, 8464 on tree, 47.683137 best solution, best possible 47.507667 (12.52 seconds)
# Cbc0010I After 34000 nodes, 8456 on tree, 47.683137 best solution, best possible 47.507667 (12.85 seconds)
# Cbc0010I After 35000 nodes, 8280 on tree, 47.683137 best solution, best possible 47.507667 (13.12 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 167 rows 129 columns
# Cbc0010I After 36000 nodes, 8459 on tree, 47.683137 best solution, best possible 47.507667 (13.50 seconds)
# Cbc0010I After 37000 nodes, 8731 on tree, 47.683137 best solution, best possible 47.507667 (13.87 seconds)
# Cbc0010I After 38000 nodes, 8734 on tree, 47.683137 best solution, best possible 47.507667 (14.25 seconds)
# Cbc0010I After 39000 nodes, 8929 on tree, 47.683137 best solution, best possible 47.507667 (14.57 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 167 rows 130 columns
# Cbc0010I After 40000 nodes, 9443 on tree, 47.683137 best solution, best possible 47.507667 (15.00 seconds)
# Cbc0010I After 41000 nodes, 9805 on tree, 47.683137 best solution, best possible 47.507667 (15.41 seconds)
# Cbc0010I After 42000 nodes, 9840 on tree, 47.683137 best solution, best possible 47.507667 (15.81 seconds)
# Cbc0010I After 43000 nodes, 10116 on tree, 47.683137 best solution, best possible 47.507667 (16.17 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 155 rows 120 columns
# Cbc0010I After 44000 nodes, 10176 on tree, 47.683137 best solution, best possible 47.507667 (16.53 seconds)
# Cbc0010I After 45000 nodes, 10528 on tree, 47.683137 best solution, best possible 47.507667 (16.82 seconds)
# Cbc0010I After 46000 nodes, 10516 on tree, 47.683137 best solution, best possible 47.507667 (17.23 seconds)
# Cbc0010I After 47000 nodes, 10385 on tree, 47.683137 best solution, best possible 47.507667 (17.52 seconds)
# Cbc0010I After 48000 nodes, 10849 on tree, 47.683137 best solution, best possible 47.507667 (17.75 seconds)
# Cbc0010I After 49000 nodes, 11299 on tree, 47.683137 best solution, best possible 47.507667 (18.03 seconds)
# Cbc0004I Integer solution of 47.658575 found after 622148 iterations and 49266 nodes (18.11 seconds)
# Cbc0010I After 50000 nodes, 9971 on tree, 47.658575 best solution, best possible 47.507667 (18.35 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 121 rows 95 columns
# Cbc0010I After 51000 nodes, 10278 on tree, 47.658575 best solution, best possible 47.507667 (18.68 seconds)
# Cbc0010I After 52000 nodes, 10477 on tree, 47.658575 best solution, best possible 47.507667 (18.95 seconds)
# Cbc0010I After 53000 nodes, 10507 on tree, 47.658575 best solution, best possible 47.507667 (19.31 seconds)
# Cbc0010I After 54000 nodes, 10475 on tree, 47.658575 best solution, best possible 47.507667 (19.66 seconds)
# Cbc0010I After 55000 nodes, 10736 on tree, 47.658575 best solution, best possible 47.507667 (19.97 seconds)
# Cbc0010I After 56000 nodes, 10897 on tree, 47.658575 best solution, best possible 47.507667 (20.23 seconds)
# Cbc0010I After 57000 nodes, 10921 on tree, 47.658575 best solution, best possible 47.507667 (20.59 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 93 rows 74 columns
# Cbc0010I After 58000 nodes, 10899 on tree, 47.658575 best solution, best possible 47.507667 (20.92 seconds)
# Cbc0010I After 59000 nodes, 11167 on tree, 47.658575 best solution, best possible 47.507667 (21.22 seconds)
# Cbc0010I After 60000 nodes, 11480 on tree, 47.658575 best solution, best possible 47.507667 (21.50 seconds)
# Cbc0010I After 61000 nodes, 11515 on tree, 47.658575 best solution, best possible 47.507667 (21.86 seconds)
# Cbc0010I After 62000 nodes, 11488 on tree, 47.658575 best solution, best possible 47.507667 (22.21 seconds)
# Cbc0010I After 63000 nodes, 11856 on tree, 47.658575 best solution, best possible 47.507667 (22.50 seconds)
# Cbc0010I After 64000 nodes, 12080 on tree, 47.658575 best solution, best possible 47.507667 (22.78 seconds)
# Cbc0010I After 65000 nodes, 12126 on tree, 47.658575 best solution, best possible 47.507667 (23.11 seconds)
# Cbc0010I After 66000 nodes, 12089 on tree, 47.658575 best solution, best possible 47.507667 (23.44 seconds)
# Cbc0010I After 67000 nodes, 12291 on tree, 47.658575 best solution, best possible 47.507667 (23.72 seconds)
# Cbc0010I After 68000 nodes, 12552 on tree, 47.658575 best solution, best possible 47.507667 (24.11 seconds)
# Cbc0010I After 69000 nodes, 12587 on tree, 47.658575 best solution, best possible 47.507667 (24.43 seconds)
# Cbc0010I After 70000 nodes, 12560 on tree, 47.658575 best solution, best possible 47.507667 (24.77 seconds)
# Cbc0010I After 71000 nodes, 12852 on tree, 47.658575 best solution, best possible 47.507667 (25.14 seconds)
# Cbc0010I After 72000 nodes, 13142 on tree, 47.658575 best solution, best possible 47.507667 (25.54 seconds)
# Cbc0010I After 73000 nodes, 13227 on tree, 47.658575 best solution, best possible 47.507667 (25.87 seconds)
# Cbc0010I After 74000 nodes, 13190 on tree, 47.658575 best solution, best possible 47.507667 (26.22 seconds)
# Cbc0010I After 75000 nodes, 13608 on tree, 47.658575 best solution, best possible 47.507667 (26.49 seconds)
# Cbc0010I After 76000 nodes, 14013 on tree, 47.658575 best solution, best possible 47.507667 (26.79 seconds)
# Cbc0010I After 77000 nodes, 14153 on tree, 47.658575 best solution, best possible 47.507667 (27.04 seconds)
# Cbc0010I After 78000 nodes, 14056 on tree, 47.658575 best solution, best possible 47.507667 (27.30 seconds)
# Cbc0010I After 79000 nodes, 14274 on tree, 47.658575 best solution, best possible 47.507667 (27.68 seconds)
# Cbc0010I After 80000 nodes, 14598 on tree, 47.658575 best solution, best possible 47.507667 (27.98 seconds)
# Cbc0010I After 81000 nodes, 14704 on tree, 47.658575 best solution, best possible 47.507667 (28.22 seconds)
# Cbc0010I After 82000 nodes, 14616 on tree, 47.658575 best solution, best possible 47.507667 (28.47 seconds)
# Cbc0010I After 83000 nodes, 14907 on tree, 47.658575 best solution, best possible 47.507667 (28.91 seconds)
# Cbc0010I After 84000 nodes, 15277 on tree, 47.658575 best solution, best possible 47.507667 (29.27 seconds)
# Cbc0010I After 85000 nodes, 15297 on tree, 47.658575 best solution, best possible 47.507667 (29.50 seconds)
# Cbc0010I After 86000 nodes, 15321 on tree, 47.658575 best solution, best possible 47.507667 (29.82 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 135 rows 105 columns
# Cbc0010I After 87000 nodes, 15750 on tree, 47.658575 best solution, best possible 47.507667 (30.10 seconds)
# Cbc0010I After 88000 nodes, 15997 on tree, 47.658575 best solution, best possible 47.507667 (30.40 seconds)
# Cbc0010I After 89000 nodes, 15998 on tree, 47.658575 best solution, best possible 47.507667 (30.68 seconds)
# Cbc0010I After 90000 nodes, 16061 on tree, 47.658575 best solution, best possible 47.507667 (30.90 seconds)
# Cbc0010I After 91000 nodes, 16493 on tree, 47.658575 best solution, best possible 47.507667 (31.14 seconds)
# Cbc0010I After 92000 nodes, 17008 on tree, 47.658575 best solution, best possible 47.507667 (31.38 seconds)
# Cbc0010I After 93000 nodes, 17025 on tree, 47.658575 best solution, best possible 47.507667 (31.66 seconds)
# Cbc0010I After 94000 nodes, 16969 on tree, 47.658575 best solution, best possible 47.507667 (31.95 seconds)
# Cbc0010I After 95000 nodes, 17527 on tree, 47.658575 best solution, best possible 47.507667 (32.17 seconds)
# Cbc0010I After 96000 nodes, 18008 on tree, 47.658575 best solution, best possible 47.507667 (32.41 seconds)
# Cbc0010I After 97000 nodes, 18017 on tree, 47.658575 best solution, best possible 47.507667 (32.68 seconds)
# Cbc0010I After 98000 nodes, 18074 on tree, 47.658575 best solution, best possible 47.507667 (32.89 seconds)
# Cbc0010I After 99000 nodes, 18416 on tree, 47.658575 best solution, best possible 47.507667 (33.13 seconds)
# Cbc0010I After 100000 nodes, 18489 on tree, 47.658575 best solution, best possible 47.507667 (33.37 seconds)
# Cbc0010I After 101000 nodes, 18439 on tree, 47.658575 best solution, best possible 47.507667 (33.62 seconds)
# Cbc0010I After 102000 nodes, 18717 on tree, 47.658575 best solution, best possible 47.507667 (33.92 seconds)
# Cbc0010I After 103000 nodes, 19076 on tree, 47.658575 best solution, best possible 47.507667 (34.16 seconds)
# Cbc0010I After 104000 nodes, 19527 on tree, 47.658575 best solution, best possible 47.507667 (34.41 seconds)
# Cbc0010I After 105000 nodes, 19499 on tree, 47.658575 best solution, best possible 47.507667 (34.67 seconds)
# Cbc0010I After 106000 nodes, 19768 on tree, 47.658575 best solution, best possible 47.507667 (34.98 seconds)
# Cbc0010I After 107000 nodes, 20198 on tree, 47.658575 best solution, best possible 47.507667 (35.22 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 141 rows 110 columns
# Cbc0010I After 108000 nodes, 20681 on tree, 47.658575 best solution, best possible 47.507667 (35.46 seconds)
# Cbc0010I After 109000 nodes, 20646 on tree, 47.658575 best solution, best possible 47.507667 (35.71 seconds)
# Cbc0010I After 110000 nodes, 20910 on tree, 47.658575 best solution, best possible 47.507667 (36.08 seconds)
# Cbc0010I After 111000 nodes, 21315 on tree, 47.658575 best solution, best possible 47.507667 (36.32 seconds)
# Cbc0010I After 112000 nodes, 21796 on tree, 47.658575 best solution, best possible 47.507667 (36.57 seconds)
# Cbc0010I After 113000 nodes, 21800 on tree, 47.658575 best solution, best possible 47.507667 (36.84 seconds)
# Cbc0010I After 114000 nodes, 22176 on tree, 47.658575 best solution, best possible 47.507667 (37.21 seconds)
# Cbc0010I After 115000 nodes, 22672 on tree, 47.658575 best solution, best possible 47.507667 (37.46 seconds)
# Cbc0010I After 116000 nodes, 23192 on tree, 47.658575 best solution, best possible 47.507667 (37.66 seconds)
# Cbc0010I After 117000 nodes, 23131 on tree, 47.658575 best solution, best possible 47.507667 (37.93 seconds)
# Cbc0010I After 118000 nodes, 23453 on tree, 47.658575 best solution, best possible 47.507667 (38.31 seconds)
# Cbc0010I After 119000 nodes, 23894 on tree, 47.658575 best solution, best possible 47.507667 (38.54 seconds)
# Cbc0010I After 120000 nodes, 24401 on tree, 47.658575 best solution, best possible 47.507667 (38.76 seconds)
# Cbc0010I After 121000 nodes, 24350 on tree, 47.658575 best solution, best possible 47.507667 (39.02 seconds)
# Cbc0010I After 122000 nodes, 24693 on tree, 47.658575 best solution, best possible 47.507667 (39.39 seconds)
# Cbc0010I After 123000 nodes, 25101 on tree, 47.658575 best solution, best possible 47.507667 (39.62 seconds)
# Cbc0010I After 124000 nodes, 25614 on tree, 47.658575 best solution, best possible 47.507667 (39.85 seconds)
# Cbc0010I After 125000 nodes, 25600 on tree, 47.658575 best solution, best possible 47.507667 (40.14 seconds)
# Cbc0010I After 126000 nodes, 25891 on tree, 47.658575 best solution, best possible 47.507667 (40.51 seconds)
# Cbc0010I After 127000 nodes, 26303 on tree, 47.658575 best solution, best possible 47.507667 (40.75 seconds)
# Cbc0010I After 128000 nodes, 26736 on tree, 47.658575 best solution, best possible 47.507667 (41.00 seconds)
# Cbc0010I After 129000 nodes, 26742 on tree, 47.658575 best solution, best possible 47.507667 (41.32 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 145 rows 115 columns
# Cbc0010I After 130000 nodes, 27091 on tree, 47.658575 best solution, best possible 47.507667 (41.65 seconds)
# Cbc0010I After 131000 nodes, 27391 on tree, 47.658575 best solution, best possible 47.507667 (41.96 seconds)
# Cbc0010I After 132000 nodes, 27889 on tree, 47.658575 best solution, best possible 47.507667 (42.20 seconds)
# Cbc0010I After 133000 nodes, 27889 on tree, 47.658575 best solution, best possible 47.507667 (42.52 seconds)
# Cbc0010I After 134000 nodes, 28235 on tree, 47.658575 best solution, best possible 47.507667 (42.88 seconds)
# Cbc0010I After 135000 nodes, 28774 on tree, 47.658575 best solution, best possible 47.507667 (43.09 seconds)
# Cbc0010I After 136000 nodes, 29241 on tree, 47.658575 best solution, best possible 47.507667 (43.34 seconds)
# Cbc0010I After 137000 nodes, 29236 on tree, 47.658575 best solution, best possible 47.507667 (43.64 seconds)
# Cbc0010I After 138000 nodes, 29709 on tree, 47.658575 best solution, best possible 47.507667 (44.01 seconds)
# Cbc0010I After 139000 nodes, 30155 on tree, 47.658575 best solution, best possible 47.507667 (44.28 seconds)
# Cbc0010I After 140000 nodes, 30663 on tree, 47.658575 best solution, best possible 47.507667 (44.53 seconds)
# Cbc0010I After 141000 nodes, 30680 on tree, 47.658575 best solution, best possible 47.507667 (44.84 seconds)
# Cbc0010I After 142000 nodes, 30963 on tree, 47.658575 best solution, best possible 47.507667 (45.14 seconds)
# Cbc0010I After 143000 nodes, 31385 on tree, 47.658575 best solution, best possible 47.507667 (45.40 seconds)
# Cbc0010I After 144000 nodes, 31834 on tree, 47.658575 best solution, best possible 47.507667 (45.65 seconds)
# Cbc0010I After 145000 nodes, 31838 on tree, 47.658575 best solution, best possible 47.507667 (45.95 seconds)
# Cbc0010I After 146000 nodes, 32093 on tree, 47.658575 best solution, best possible 47.507667 (46.25 seconds)
# Cbc0010I After 147000 nodes, 32546 on tree, 47.658575 best solution, best possible 47.507667 (46.48 seconds)
# Cbc0010I After 148000 nodes, 32980 on tree, 47.658575 best solution, best possible 47.507667 (46.75 seconds)
# Cbc0010I After 149000 nodes, 32975 on tree, 47.658575 best solution, best possible 47.507667 (47.10 seconds)
# Cbc0010I After 150000 nodes, 33268 on tree, 47.658575 best solution, best possible 47.507667 (47.45 seconds)
# Cbc0010I After 151000 nodes, 33664 on tree, 47.658575 best solution, best possible 47.507667 (47.72 seconds)
# Cbc0010I After 152000 nodes, 34046 on tree, 47.658575 best solution, best possible 47.507667 (48.02 seconds)
# Cbc0010I After 153000 nodes, 34047 on tree, 47.658575 best solution, best possible 47.507667 (48.34 seconds)
# Cbc0010I After 154000 nodes, 34475 on tree, 47.658575 best solution, best possible 47.507667 (48.72 seconds)
# Cbc0010I After 155000 nodes, 34928 on tree, 47.658575 best solution, best possible 47.507667 (48.95 seconds)
# Cbc0010I After 156000 nodes, 35406 on tree, 47.658575 best solution, best possible 47.507667 (49.19 seconds)
# Cbc0010I After 157000 nodes, 35404 on tree, 47.658575 best solution, best possible 47.507667 (49.51 seconds)
# Cbc0010I After 158000 nodes, 35732 on tree, 47.658575 best solution, best possible 47.507667 (49.87 seconds)
# Cbc0010I After 159000 nodes, 36153 on tree, 47.658575 best solution, best possible 47.507667 (50.10 seconds)
# Cbc0010I After 160000 nodes, 36591 on tree, 47.658575 best solution, best possible 47.507667 (50.36 seconds)
# Cbc0010I After 161000 nodes, 36591 on tree, 47.658575 best solution, best possible 47.507667 (50.68 seconds)
# Cbc0010I After 162000 nodes, 36884 on tree, 47.658575 best solution, best possible 47.507667 (51.03 seconds)
# Cbc0010I After 163000 nodes, 37218 on tree, 47.658575 best solution, best possible 47.507667 (51.28 seconds)
# Cbc0010I After 164000 nodes, 37545 on tree, 47.658575 best solution, best possible 47.507667 (51.56 seconds)
# Cbc0010I After 165000 nodes, 37550 on tree, 47.658575 best solution, best possible 47.507667 (51.91 seconds)
# Cbc0010I After 166000 nodes, 37794 on tree, 47.658575 best solution, best possible 47.507667 (52.32 seconds)
# Cbc0010I After 167000 nodes, 38070 on tree, 47.658575 best solution, best possible 47.507667 (52.56 seconds)
# Cbc0010I After 168000 nodes, 38528 on tree, 47.658575 best solution, best possible 47.507667 (52.79 seconds)
# Cbc0010I After 169000 nodes, 38529 on tree, 47.658575 best solution, best possible 47.507667 (53.10 seconds)
# Cbc0010I After 170000 nodes, 38421 on tree, 47.658575 best solution, best possible 47.507667 (53.38 seconds)
# Cbc0010I After 171000 nodes, 38864 on tree, 47.658575 best solution, best possible 47.507667 (53.62 seconds)
# Cbc0010I After 172000 nodes, 39338 on tree, 47.658575 best solution, best possible 47.507667 (53.87 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 139 rows 108 columns
# Cbc0010I After 173000 nodes, 39340 on tree, 47.658575 best solution, best possible 47.507667 (54.18 seconds)
# Cbc0010I After 174000 nodes, 39525 on tree, 47.658575 best solution, best possible 47.507667 (54.49 seconds)
# Cbc0010I After 175000 nodes, 39950 on tree, 47.658575 best solution, best possible 47.507667 (54.73 seconds)
# Cbc0010I After 176000 nodes, 40416 on tree, 47.658575 best solution, best possible 47.507667 (54.97 seconds)
# Cbc0010I After 177000 nodes, 40417 on tree, 47.658575 best solution, best possible 47.507667 (55.27 seconds)
# Cbc0010I After 178000 nodes, 40697 on tree, 47.658575 best solution, best possible 47.507667 (55.60 seconds)
# Cbc0010I After 179000 nodes, 41119 on tree, 47.658575 best solution, best possible 47.507667 (55.82 seconds)
# Cbc0010I After 180000 nodes, 41575 on tree, 47.658575 best solution, best possible 47.507667 (56.06 seconds)
# Cbc0010I After 181000 nodes, 41582 on tree, 47.658575 best solution, best possible 47.507667 (56.33 seconds)
# Cbc0010I After 182000 nodes, 41798 on tree, 47.658575 best solution, best possible 47.507667 (56.68 seconds)
# Cbc0010I After 183000 nodes, 42269 on tree, 47.658575 best solution, best possible 47.507667 (56.89 seconds)
# Cbc0010I After 184000 nodes, 42750 on tree, 47.658575 best solution, best possible 47.507667 (57.12 seconds)
# Cbc0010I After 185000 nodes, 42760 on tree, 47.658575 best solution, best possible 47.507667 (57.40 seconds)
# Cbc0010I After 186000 nodes, 42687 on tree, 47.658575 best solution, best possible 47.507667 (57.75 seconds)
# Cbc0010I After 187000 nodes, 43153 on tree, 47.658575 best solution, best possible 47.507667 (57.97 seconds)
# Cbc0010I After 188000 nodes, 43627 on tree, 47.658575 best solution, best possible 47.507667 (58.20 seconds)
# Cbc0010I After 189000 nodes, 43630 on tree, 47.658575 best solution, best possible 47.507667 (58.49 seconds)
# Cbc0010I After 190000 nodes, 43871 on tree, 47.658575 best solution, best possible 47.507667 (58.81 seconds)
# Cbc0010I After 191000 nodes, 44228 on tree, 47.658575 best solution, best possible 47.507667 (59.03 seconds)
# Cbc0010I After 192000 nodes, 44677 on tree, 47.658575 best solution, best possible 47.507667 (59.26 seconds)
# Cbc0010I After 193000 nodes, 44681 on tree, 47.658575 best solution, best possible 47.507667 (59.55 seconds)
# Cbc0010I After 194000 nodes, 45060 on tree, 47.658575 best solution, best possible 47.507667 (59.90 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 145 rows 113 columns
# Cbc0010I After 195000 nodes, 45467 on tree, 47.658575 best solution, best possible 47.507667 (60.13 seconds)
# Cbc0010I After 196000 nodes, 45894 on tree, 47.658575 best solution, best possible 47.507667 (60.40 seconds)
# Cbc0010I After 197000 nodes, 45888 on tree, 47.658575 best solution, best possible 47.507667 (60.74 seconds)
# Cbc0010I After 198000 nodes, 46185 on tree, 47.658575 best solution, best possible 47.507667 (61.09 seconds)
# Cbc0010I After 199000 nodes, 46486 on tree, 47.658575 best solution, best possible 47.507667 (61.31 seconds)
# Cbc0010I After 200000 nodes, 47028 on tree, 47.658575 best solution, best possible 47.507667 (61.53 seconds)
# Cbc0010I After 201000 nodes, 47028 on tree, 47.658575 best solution, best possible 47.507667 (61.82 seconds)
# Cbc0010I After 202000 nodes, 47384 on tree, 47.658575 best solution, best possible 47.507667 (62.18 seconds)
# Cbc0010I After 203000 nodes, 47808 on tree, 47.658575 best solution, best possible 47.507667 (62.43 seconds)
# Cbc0010I After 204000 nodes, 48314 on tree, 47.658575 best solution, best possible 47.507667 (62.67 seconds)
# Cbc0010I After 205000 nodes, 48313 on tree, 47.658575 best solution, best possible 47.507667 (62.96 seconds)
# Cbc0010I After 206000 nodes, 48690 on tree, 47.658575 best solution, best possible 47.507667 (63.32 seconds)
# Cbc0010I After 207000 nodes, 49095 on tree, 47.658575 best solution, best possible 47.507667 (63.52 seconds)
# Cbc0010I After 208000 nodes, 49485 on tree, 47.658575 best solution, best possible 47.507667 (63.74 seconds)
# Cbc0010I After 209000 nodes, 49484 on tree, 47.658575 best solution, best possible 47.507667 (64.05 seconds)
# Cbc0010I After 210000 nodes, 49774 on tree, 47.658575 best solution, best possible 47.507667 (64.35 seconds)
# Cbc0010I After 211000 nodes, 50166 on tree, 47.658575 best solution, best possible 47.507667 (64.59 seconds)
# Cbc0010I After 212000 nodes, 50720 on tree, 47.658575 best solution, best possible 47.507667 (64.77 seconds)
# Cbc0010I After 213000 nodes, 50721 on tree, 47.658575 best solution, best possible 47.507667 (65.08 seconds)
# Cbc0010I After 214000 nodes, 51074 on tree, 47.658575 best solution, best possible 47.507667 (65.44 seconds)
# Cbc0010I After 215000 nodes, 51616 on tree, 47.658575 best solution, best possible 47.507667 (65.62 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 139 rows 108 columns
# Cbc0010I After 216000 nodes, 52122 on tree, 47.658575 best solution, best possible 47.507667 (65.83 seconds)
# Cbc0010I After 217000 nodes, 52123 on tree, 47.658575 best solution, best possible 47.507667 (66.15 seconds)
# Cbc0010I After 218000 nodes, 52319 on tree, 47.658575 best solution, best possible 47.507667 (66.49 seconds)
# Cbc0010I After 219000 nodes, 52742 on tree, 47.658575 best solution, best possible 47.507667 (66.77 seconds)
# Cbc0010I After 220000 nodes, 53227 on tree, 47.658575 best solution, best possible 47.507667 (66.99 seconds)
# Cbc0010I After 221000 nodes, 53233 on tree, 47.658575 best solution, best possible 47.507667 (67.31 seconds)
# Cbc0010I After 222000 nodes, 53434 on tree, 47.658575 best solution, best possible 47.507667 (67.61 seconds)
# Cbc0010I After 223000 nodes, 53784 on tree, 47.658575 best solution, best possible 47.507667 (67.82 seconds)
# Cbc0010I After 224000 nodes, 54169 on tree, 47.658575 best solution, best possible 47.507667 (68.04 seconds)
# Cbc0010I After 225000 nodes, 54171 on tree, 47.658575 best solution, best possible 47.507667 (68.34 seconds)
# Cbc0010I After 226000 nodes, 54348 on tree, 47.658575 best solution, best possible 47.507667 (68.72 seconds)
# Cbc0010I After 227000 nodes, 54689 on tree, 47.658575 best solution, best possible 47.507667 (68.95 seconds)
# Cbc0010I After 228000 nodes, 55101 on tree, 47.658575 best solution, best possible 47.507667 (69.17 seconds)
# Cbc0010I After 229000 nodes, 55103 on tree, 47.658575 best solution, best possible 47.507667 (69.48 seconds)
# Cbc0010I After 230000 nodes, 55181 on tree, 47.658575 best solution, best possible 47.507667 (69.82 seconds)
# Cbc0010I After 231000 nodes, 55507 on tree, 47.658575 best solution, best possible 47.507667 (70.07 seconds)
# Cbc0010I After 232000 nodes, 55950 on tree, 47.658575 best solution, best possible 47.507667 (70.30 seconds)
# Cbc0010I After 233000 nodes, 55955 on tree, 47.658575 best solution, best possible 47.507667 (70.60 seconds)
# Cbc0010I After 234000 nodes, 56224 on tree, 47.658575 best solution, best possible 47.507667 (71.00 seconds)
# Cbc0010I After 235000 nodes, 56640 on tree, 47.658575 best solution, best possible 47.507667 (71.23 seconds)
# Cbc0010I After 236000 nodes, 57083 on tree, 47.658575 best solution, best possible 47.507667 (71.45 seconds)
# Cbc0010I After 237000 nodes, 57092 on tree, 47.658575 best solution, best possible 47.507667 (71.76 seconds)
# Cbc0010I After 238000 nodes, 57239 on tree, 47.658575 best solution, best possible 47.507667 (72.09 seconds)
# Cbc0010I After 239000 nodes, 57626 on tree, 47.658575 best solution, best possible 47.507667 (72.33 seconds)
# Cbc0010I After 240000 nodes, 58058 on tree, 47.658575 best solution, best possible 47.507667 (72.56 seconds)
# Cbc0010I After 241000 nodes, 58059 on tree, 47.658575 best solution, best possible 47.507667 (72.86 seconds)
# Cbc0010I After 242000 nodes, 58318 on tree, 47.658575 best solution, best possible 47.507667 (73.19 seconds)
# Cbc0010I After 243000 nodes, 58717 on tree, 47.658575 best solution, best possible 47.507667 (73.41 seconds)
# Cbc0010I After 244000 nodes, 59164 on tree, 47.658575 best solution, best possible 47.507667 (73.63 seconds)
# Cbc0010I After 245000 nodes, 59165 on tree, 47.658575 best solution, best possible 47.507667 (73.92 seconds)
# Cbc0010I After 246000 nodes, 59376 on tree, 47.658575 best solution, best possible 47.507667 (74.28 seconds)
# Cbc0010I After 247000 nodes, 59789 on tree, 47.658575 best solution, best possible 47.507667 (74.50 seconds)
# Cbc0010I After 248000 nodes, 60235 on tree, 47.658575 best solution, best possible 47.507667 (74.73 seconds)
# Cbc0010I After 249000 nodes, 60249 on tree, 47.658575 best solution, best possible 47.507667 (75.04 seconds)
# Cbc0010I After 250000 nodes, 60534 on tree, 47.658575 best solution, best possible 47.507667 (75.40 seconds)
# Cbc0010I After 251000 nodes, 60839 on tree, 47.658575 best solution, best possible 47.507667 (75.70 seconds)
# Cbc0010I After 252000 nodes, 61111 on tree, 47.658575 best solution, best possible 47.507667 (76.00 seconds)
# Cbc0010I After 253000 nodes, 61115 on tree, 47.658575 best solution, best possible 47.507667 (76.31 seconds)
# Cbc0010I After 254000 nodes, 61325 on tree, 47.658575 best solution, best possible 47.507667 (76.63 seconds)
# Cbc0010I After 255000 nodes, 61528 on tree, 47.658575 best solution, best possible 47.507667 (76.98 seconds)
# Cbc0010I After 256000 nodes, 61485 on tree, 47.658575 best solution, best possible 47.507667 (77.33 seconds)
# Cbc0010I After 257000 nodes, 61482 on tree, 47.658575 best solution, best possible 47.507667 (77.63 seconds)
# Cbc0010I After 258000 nodes, 61755 on tree, 47.658575 best solution, best possible 47.507667 (77.94 seconds)
# Cbc0010I After 259000 nodes, 62134 on tree, 47.658575 best solution, best possible 47.507667 (78.17 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 147 rows 114 columns
# Cbc0010I After 260000 nodes, 62633 on tree, 47.658575 best solution, best possible 47.507667 (78.38 seconds)
# Cbc0010I After 261000 nodes, 62638 on tree, 47.658575 best solution, best possible 47.507667 (78.67 seconds)
# Cbc0010I After 262000 nodes, 62906 on tree, 47.658575 best solution, best possible 47.507667 (78.99 seconds)
# Cbc0010I After 263000 nodes, 63356 on tree, 47.658575 best solution, best possible 47.507667 (79.19 seconds)
# Cbc0010I After 264000 nodes, 63847 on tree, 47.658575 best solution, best possible 47.507667 (79.39 seconds)
# Cbc0010I After 265000 nodes, 63851 on tree, 47.658575 best solution, best possible 47.507667 (79.70 seconds)
# Cbc0010I After 266000 nodes, 64077 on tree, 47.658575 best solution, best possible 47.507667 (79.95 seconds)
# Cbc0010I After 267000 nodes, 64522 on tree, 47.658575 best solution, best possible 47.507667 (80.15 seconds)
# Cbc0010I After 268000 nodes, 65005 on tree, 47.658575 best solution, best possible 47.507667 (80.35 seconds)
# Cbc0010I After 269000 nodes, 65018 on tree, 47.658575 best solution, best possible 47.507667 (80.63 seconds)
# Cbc0010I After 270000 nodes, 65170 on tree, 47.658575 best solution, best possible 47.507667 (80.89 seconds)
# Cbc0010I After 271000 nodes, 65582 on tree, 47.658575 best solution, best possible 47.507667 (81.08 seconds)
# Cbc0010I After 272000 nodes, 66055 on tree, 47.658575 best solution, best possible 47.507667 (81.27 seconds)
# Cbc0010I After 273000 nodes, 66047 on tree, 47.658575 best solution, best possible 47.507667 (81.58 seconds)
# Cbc0010I After 274000 nodes, 66406 on tree, 47.658575 best solution, best possible 47.507667 (81.91 seconds)
# Cbc0010I After 275000 nodes, 66836 on tree, 47.658575 best solution, best possible 47.507667 (82.11 seconds)
# Cbc0010I After 276000 nodes, 67285 on tree, 47.658575 best solution, best possible 47.507667 (82.30 seconds)
# Cbc0010I After 277000 nodes, 67294 on tree, 47.658575 best solution, best possible 47.507667 (82.57 seconds)
# Cbc0010I After 278000 nodes, 67595 on tree, 47.658575 best solution, best possible 47.507667 (82.91 seconds)
# Cbc0010I After 279000 nodes, 67917 on tree, 47.658575 best solution, best possible 47.507667 (83.13 seconds)
# Cbc0010I After 280000 nodes, 68398 on tree, 47.658575 best solution, best possible 47.507667 (83.32 seconds)
# Cbc0010I After 281000 nodes, 68403 on tree, 47.658575 best solution, best possible 47.507667 (83.60 seconds)
# Cbc0010I After 282000 nodes, 68645 on tree, 47.658575 best solution, best possible 47.507667 (83.94 seconds)
# Cbc0010I After 283000 nodes, 69036 on tree, 47.658575 best solution, best possible 47.507667 (84.12 seconds)
# Cbc0010I After 284000 nodes, 69530 on tree, 47.658575 best solution, best possible 47.507667 (84.31 seconds)
# Cbc0010I After 285000 nodes, 69530 on tree, 47.658575 best solution, best possible 47.507667 (84.60 seconds)
# Cbc0010I After 286000 nodes, 69472 on tree, 47.658575 best solution, best possible 47.507667 (84.90 seconds)
# Cbc0010I After 287000 nodes, 69944 on tree, 47.658575 best solution, best possible 47.507667 (85.09 seconds)
# Cbc0010I After 288000 nodes, 70414 on tree, 47.658575 best solution, best possible 47.507667 (85.28 seconds)
# Cbc0010I After 289000 nodes, 70416 on tree, 47.658575 best solution, best possible 47.507667 (85.57 seconds)
# Cbc0010I After 290000 nodes, 70371 on tree, 47.658575 best solution, best possible 47.507667 (85.93 seconds)
# Cbc0010I After 291000 nodes, 70783 on tree, 47.658575 best solution, best possible 47.507667 (86.14 seconds)
# Cbc0010I After 292000 nodes, 71331 on tree, 47.658575 best solution, best possible 47.507667 (86.31 seconds)
# Cbc0010I After 293000 nodes, 71334 on tree, 47.658575 best solution, best possible 47.507667 (86.60 seconds)
# Cbc0010I After 294000 nodes, 71256 on tree, 47.658575 best solution, best possible 47.507667 (86.92 seconds)
# Cbc0010I After 295000 nodes, 71715 on tree, 47.658575 best solution, best possible 47.507667 (87.10 seconds)
# Cbc0010I After 296000 nodes, 72190 on tree, 47.658575 best solution, best possible 47.507667 (87.28 seconds)
# Cbc0010I After 297000 nodes, 72192 on tree, 47.658575 best solution, best possible 47.507667 (87.59 seconds)
# Cbc0010I After 298000 nodes, 72240 on tree, 47.658575 best solution, best possible 47.507667 (87.90 seconds)
# Cbc0010I After 299000 nodes, 72718 on tree, 47.658575 best solution, best possible 47.507667 (88.12 seconds)
# Cbc0010I After 300000 nodes, 73218 on tree, 47.658575 best solution, best possible 47.507667 (88.32 seconds)
# Cbc0010I After 301000 nodes, 73221 on tree, 47.658575 best solution, best possible 47.507667 (88.62 seconds)
# Cbc0010I After 302000 nodes, 73316 on tree, 47.658575 best solution, best possible 47.507667 (88.95 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 121 rows 94 columns
# Cbc0010I After 303000 nodes, 73721 on tree, 47.658575 best solution, best possible 47.507667 (89.16 seconds)
# Cbc0010I After 304000 nodes, 74176 on tree, 47.658575 best solution, best possible 47.507667 (89.37 seconds)
# Cbc0010I After 305000 nodes, 74175 on tree, 47.658575 best solution, best possible 47.507667 (89.67 seconds)
# Cbc0010I After 306000 nodes, 74470 on tree, 47.658575 best solution, best possible 47.507667 (90.00 seconds)
# Cbc0010I After 307000 nodes, 74932 on tree, 47.658575 best solution, best possible 47.507667 (90.20 seconds)
# Cbc0010I After 308000 nodes, 75418 on tree, 47.658575 best solution, best possible 47.507667 (90.41 seconds)
# Cbc0010I After 309000 nodes, 75423 on tree, 47.658575 best solution, best possible 47.507667 (90.72 seconds)
# Cbc0010I After 310000 nodes, 75577 on tree, 47.658575 best solution, best possible 47.507667 (91.01 seconds)
# Cbc0010I After 311000 nodes, 75982 on tree, 47.658575 best solution, best possible 47.507667 (91.21 seconds)
# Cbc0010I After 312000 nodes, 76463 on tree, 47.658575 best solution, best possible 47.507667 (91.42 seconds)
# Cbc0010I After 313000 nodes, 76471 on tree, 47.658575 best solution, best possible 47.507667 (91.71 seconds)
# Cbc0010I After 314000 nodes, 76698 on tree, 47.658575 best solution, best possible 47.507667 (92.05 seconds)
# Cbc0010I After 315000 nodes, 77059 on tree, 47.658575 best solution, best possible 47.507667 (92.25 seconds)
# Cbc0010I After 316000 nodes, 77523 on tree, 47.658575 best solution, best possible 47.507667 (92.48 seconds)
# Cbc0010I After 317000 nodes, 77526 on tree, 47.658575 best solution, best possible 47.507667 (92.77 seconds)
# Cbc0010I After 318000 nodes, 77751 on tree, 47.658575 best solution, best possible 47.507667 (93.09 seconds)
# Cbc0010I After 319000 nodes, 78145 on tree, 47.658575 best solution, best possible 47.507667 (93.30 seconds)
# Cbc0010I After 320000 nodes, 78603 on tree, 47.658575 best solution, best possible 47.507667 (93.52 seconds)
# Cbc0010I After 321000 nodes, 78599 on tree, 47.658575 best solution, best possible 47.507667 (93.83 seconds)
# Cbc0010I After 322000 nodes, 78809 on tree, 47.658575 best solution, best possible 47.507667 (94.13 seconds)
# Cbc0010I After 323000 nodes, 79218 on tree, 47.658575 best solution, best possible 47.507667 (94.33 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 133 rows 104 columns
# Cbc0010I After 324000 nodes, 79573 on tree, 47.658575 best solution, best possible 47.507667 (94.55 seconds)
# Cbc0010I After 325000 nodes, 79582 on tree, 47.658575 best solution, best possible 47.507667 (94.86 seconds)
# Cbc0010I After 326000 nodes, 79797 on tree, 47.658575 best solution, best possible 47.507667 (95.22 seconds)
# Cbc0010I After 327000 nodes, 80071 on tree, 47.658575 best solution, best possible 47.507667 (95.44 seconds)
# Cbc0010I After 328000 nodes, 80471 on tree, 47.658575 best solution, best possible 47.507667 (95.66 seconds)
# Cbc0010I After 329000 nodes, 80479 on tree, 47.658575 best solution, best possible 47.507667 (95.97 seconds)
# Cbc0010I After 330000 nodes, 80788 on tree, 47.658575 best solution, best possible 47.507667 (96.34 seconds)
# Cbc0010I After 331000 nodes, 81292 on tree, 47.658575 best solution, best possible 47.507667 (96.54 seconds)
# Cbc0010I After 332000 nodes, 81777 on tree, 47.658575 best solution, best possible 47.507667 (96.74 seconds)
# Cbc0010I After 333000 nodes, 81778 on tree, 47.658575 best solution, best possible 47.507667 (97.04 seconds)
# Cbc0010I After 334000 nodes, 82111 on tree, 47.658575 best solution, best possible 47.507667 (97.37 seconds)
# Cbc0010I After 335000 nodes, 82585 on tree, 47.658575 best solution, best possible 47.507667 (97.56 seconds)
# Cbc0010I After 336000 nodes, 83060 on tree, 47.658575 best solution, best possible 47.507667 (97.77 seconds)
# Cbc0010I After 337000 nodes, 83057 on tree, 47.658575 best solution, best possible 47.507667 (98.06 seconds)
# Cbc0010I After 338000 nodes, 83200 on tree, 47.658575 best solution, best possible 47.507667 (98.38 seconds)
# Cbc0010I After 339000 nodes, 83674 on tree, 47.658575 best solution, best possible 47.507667 (98.59 seconds)
# ...
# Cbc0010I After 479000 nodes, 117202 on tree, 47.658575 best solution, best possible 47.507667 (141.19 seconds)
# Cbc0010I After 480000 nodes, 117087 on tree, 47.658575 best solution, best possible 47.507667 (141.48 seconds)
# Cbc0010I After 481000 nodes, 117102 on tree, 47.658575 best solution, best possible 47.507667 (141.81 seconds)
# Cbc0010I After 482000 nodes, 117510 on tree, 47.658575 best solution, best possible 47.507667 (142.22 seconds)
# Cbc0010I After 483000 nodes, 117505 on tree, 47.658575 best solution, best possible 47.507667 (142.53 seconds)
# Cbc0010I After 484000 nodes, 117485 on tree, 47.658575 best solution, best possible 47.507667 (142.85 seconds)
# Cbc0010I After 485000 nodes, 117487 on tree, 47.658575 best solution, best possible 47.507667 (143.17 seconds)
# Cbc0010I After 486000 nodes, 117488 on tree, 47.658575 best solution, best possible 47.507667 (143.48 seconds)
# Cbc0010I After 487000 nodes, 117479 on tree, 47.658575 best solution, best possible 47.507667 (143.82 seconds)
# Cbc0010I After 488000 nodes, 117467 on tree, 47.658575 best solution, best possible 47.507667 (144.16 seconds)
# Cbc0010I After 489000 nodes, 117466 on tree, 47.658575 best solution, best possible 47.507667 (144.51 seconds)
# Cbc0010I After 490000 nodes, 117467 on tree, 47.658575 best solution, best possible 47.507667 (144.82 seconds)
# Cbc0010I After 491000 nodes, 117449 on tree, 47.658575 best solution, best possible 47.507667 (145.16 seconds)
# Cbc0010I After 492000 nodes, 117424 on tree, 47.658575 best solution, best possible 47.507667 (145.52 seconds)
# Cbc0010I After 493000 nodes, 117406 on tree, 47.658575 best solution, best possible 47.507667 (145.84 seconds)
# Cbc0010I After 494000 nodes, 117404 on tree, 47.658575 best solution, best possible 47.507667 (146.20 seconds)
# Cbc0010I After 495000 nodes, 117368 on tree, 47.658575 best solution, best possible 47.507667 (146.54 seconds)
# Cbc0010I After 496000 nodes, 117351 on tree, 47.658575 best solution, best possible 47.507667 (146.85 seconds)
# Cbc0010I After 497000 nodes, 117308 on tree, 47.658575 best solution, best possible 47.507667 (147.21 seconds)
# Cbc0010I After 498000 nodes, 117297 on tree, 47.658575 best solution, best possible 47.507667 (147.54 seconds)
# Cbc0010I After 499000 nodes, 117297 on tree, 47.658575 best solution, best possible 47.507667 (147.84 seconds)
# Cbc0010I After 500000 nodes, 117299 on tree, 47.658575 best solution, best possible 47.507667 (148.13 seconds)
# Cbc0010I After 501000 nodes, 117299 on tree, 47.658575 best solution, best possible 47.507667 (148.42 seconds)
# Cbc0010I After 502000 nodes, 117303 on tree, 47.658575 best solution, best possible 47.507667 (148.71 seconds)
# Cbc0010I After 503000 nodes, 117304 on tree, 47.658575 best solution, best possible 47.507667 (149.02 seconds)
# Cbc0010I After 504000 nodes, 117300 on tree, 47.658575 best solution, best possible 47.507667 (149.33 seconds)
# Cbc0010I After 505000 nodes, 117298 on tree, 47.658575 best solution, best possible 47.507667 (149.60 seconds)
# Cbc0010I After 506000 nodes, 117302 on tree, 47.658575 best solution, best possible 47.507667 (149.89 seconds)
# Cbc0010I After 507000 nodes, 117300 on tree, 47.658575 best solution, best possible 47.507667 (150.18 seconds)
# Cbc0010I After 508000 nodes, 117299 on tree, 47.658575 best solution, best possible 47.507667 (150.49 seconds)
# Cbc0010I After 509000 nodes, 117297 on tree, 47.658575 best solution, best possible 47.507667 (150.80 seconds)
# Cbc0010I After 510000 nodes, 117303 on tree, 47.658575 best solution, best possible 47.507667 (151.09 seconds)
# Cbc0010I After 511000 nodes, 117300 on tree, 47.658575 best solution, best possible 47.507667 (151.40 seconds)
# Cbc0010I After 512000 nodes, 117301 on tree, 47.658575 best solution, best possible 47.507667 (151.68 seconds)
# Cbc0010I After 513000 nodes, 117295 on tree, 47.658575 best solution, best possible 47.507667 (151.97 seconds)
# Cbc0010I After 514000 nodes, 117303 on tree, 47.658575 best solution, best possible 47.507667 (152.25 seconds)
# Cbc0010I After 515000 nodes, 117295 on tree, 47.658575 best solution, best possible 47.507667 (152.56 seconds)
# Cbc0010I After 516000 nodes, 117301 on tree, 47.658575 best solution, best possible 47.507667 (152.85 seconds)
# Cbc0010I After 517000 nodes, 117300 on tree, 47.658575 best solution, best possible 47.507667 (153.15 seconds)
# Cbc0010I After 518000 nodes, 117301 on tree, 47.658575 best solution, best possible 47.507667 (153.45 seconds)
# Cbc0038I Full problem 339 rows 268 columns, reduced to 135 rows 105 columns
# Cbc0010I After 519000 nodes, 117304 on tree, 47.658575 best solution, best possible 47.507667 (153.76 seconds)
# Cbc0010I After 520000 nodes, 117303 on tree, 47.658575 best solution, best possible 47.507667 (154.04 seconds)
# Cbc0010I After 521000 nodes, 117300 on tree, 47.658575 best solution, best possible 47.507667 (154.33 seconds)
# Cbc0010I After 522000 nodes, 117302 on tree, 47.658575 best solution, best possible 47.507667 (154.64 seconds)
# Cbc0010I After 523000 nodes, 117296 on tree, 47.658575 best solution, best possible 47.507667 (154.91 seconds)
# Cbc0010I After 524000 nodes, 117294 on tree, 47.658575 best solution, best possible 47.507667 (155.22 seconds)
# Cbc0010I After 525000 nodes, 117295 on tree, 47.658575 best solution, best possible 47.507667 (155.52 seconds)
# Cbc0010I After 526000 nodes, 117293 on tree, 47.658575 best solution, best possible 47.507667 (155.90 seconds)
# Cbc0010I After 527000 nodes, 117291 on tree, 47.658575 best solution, best possible 47.507667 (156.22 seconds)
# Cbc0010I After 528000 nodes, 117297 on tree, 47.658575 best solution, best possible 47.507667 (156.55 seconds)
# Cbc0010I After 529000 nodes, 117290 on tree, 47.658575 best solution, best possible 47.507667 (156.86 seconds)
# Cbc0010I After 530000 nodes, 117293 on tree, 47.658575 best solution, best possible 47.507667 (157.19 seconds)
# Cbc0010I After 531000 nodes, 117292 on tree, 47.658575 best solution, best possible 47.507667 (157.52 seconds)
# Cbc0010I After 532000 nodes, 117294 on tree, 47.658575 best solution, best possible 47.507667 (157.85 seconds)
# Cbc0010I After 533000 nodes, 117295 on tree, 47.658575 best solution, best possible 47.507667 (158.18 seconds)
# Cbc0010I After 534000 nodes, 117296 on tree, 47.658575 best solution, best possible 47.507667 (158.51 seconds)
# Cbc0010I After 535000 nodes, 117287 on tree, 47.658575 best solution, best possible 47.507667 (158.82 seconds)
# Cbc0010I After 536000 nodes, 117289 on tree, 47.658575 best solution, best possible 47.507667 (159.15 seconds)
# Cbc0010I After 537000 nodes, 117293 on tree, 47.658575 best solution, best possible 47.507667 (159.47 seconds)
# Cbc0010I After 538000 nodes, 117293 on tree, 47.658575 best solution, best possible 47.507667 (159.80 seconds)
# Cbc0010I After 539000 nodes, 117296 on tree, 47.658575 best solution, best possible 47.507667 (160.13 seconds)
# Cbc0010I After 540000 nodes, 117294 on tree, 47.658575 best solution, best possible 47.507667 (160.46 seconds)
# Cbc0010I After 541000 nodes, 117290 on tree, 47.658575 best solution, best possible 47.507667 (160.78 seconds)
# Cbc0010I After 542000 nodes, 117292 on tree, 47.658575 best solution, best possible 47.507667 (161.09 seconds)
# Cbc0010I After 543000 nodes, 117292 on tree, 47.658575 best solution, best possible 47.507667 (161.41 seconds)
# Cbc0010I After 544000 nodes, 117293 on tree, 47.658575 best solution, best possible 47.507667 (161.74 seconds)
# Cbc0010I After 545000 nodes, 117289 on tree, 47.658575 best solution, best possible 47.507667 (162.07 seconds)
# Cbc0010I After 546000 nodes, 117291 on tree, 47.658575 best solution, best possible 47.507667 (162.40 seconds)
# Cbc0010I After 547000 nodes, 117289 on tree, 47.658575 best solution, best possible 47.507667 (162.74 seconds)
# Cbc0010I After 548000 nodes, 117288 on tree, 47.658575 best solution, best possible 47.507667 (163.06 seconds)
# Cbc0010I After 549000 nodes, 117285 on tree, 47.658575 best solution, best possible 47.507667 (163.38 seconds)
# Cbc0010I After 550000 nodes, 117287 on tree, 47.658575 best solution, best possible 47.507667 (163.71 seconds)
# Cbc0010I After 551000 nodes, 117288 on tree, 47.658575 best solution, best possible 47.507667 (164.03 seconds)
# Cbc0010I After 552000 nodes, 117291 on tree, 47.658575 best solution, best possible 47.507667 (164.37 seconds)
# Cbc0010I After 553000 nodes, 117293 on tree, 47.658575 best solution, best possible 47.507667 (164.69 seconds)
# Cbc0010I After 554000 nodes, 117291 on tree, 47.658575 best solution, best possible 47.507667 (165.02 seconds)
# Cbc0010I After 555000 nodes, 117289 on tree, 47.658575 best solution, best possible 47.507667 (165.34 seconds)
# Cbc0010I After 556000 nodes, 117293 on tree, 47.658575 best solution, best possible 47.507667 (165.66 seconds)
# Cbc0010I After 557000 nodes, 117284 on tree, 47.658575 best solution, best possible 47.507667 (165.96 seconds)
# Cbc0010I After 558000 nodes, 117282 on tree, 47.658575 best solution, best possible 47.507667 (166.29 seconds)
# Cbc0010I After 559000 nodes, 117286 on tree, 47.658575 best solution, best possible 47.507667 (166.62 seconds)
# Cbc0010I After 560000 nodes, 117289 on tree, 47.658575 best solution, best possible 47.507667 (166.94 seconds)
# Cbc0010I After 561000 nodes, 117287 on tree, 47.658575 best solution, best possible 47.507667 (167.27 seconds)
# Cbc0010I After 562000 nodes, 117286 on tree, 47.658575 best solution, best possible 47.507667 (167.59 seconds)
# Cbc0010I After 563000 nodes, 117286 on tree, 47.658575 best solution, best possible 47.507667 (167.92 seconds)
# Cbc0010I After 564000 nodes, 117285 on tree, 47.658575 best solution, best possible 47.507667 (168.23 seconds)
# Cbc0010I After 565000 nodes, 117284 on tree, 47.658575 best solution, best possible 47.507667 (168.56 seconds)
# Cbc0010I After 566000 nodes, 117282 on tree, 47.658575 best solution, best possible 47.507667 (168.86 seconds)
# Cbc0010I After 567000 nodes, 117275 on tree, 47.658575 best solution, best possible 47.507667 (169.16 seconds)
# Cbc0010I After 568000 nodes, 117270 on tree, 47.658575 best solution, best possible 47.507667 (169.43 seconds)
# Cbc0010I After 569000 nodes, 117259 on tree, 47.658575 best solution, best possible 47.507667 (169.70 seconds)
# Cbc0010I After 570000 nodes, 117254 on tree, 47.658575 best solution, best possible 47.507667 (169.94 seconds)
# Cbc0010I After 571000 nodes, 117246 on tree, 47.658575 best solution, best possible 47.507667 (170.21 seconds)
# Cbc0010I After 572000 nodes, 117246 on tree, 47.658575 best solution, best possible 47.507667 (170.45 seconds)
# Cbc0010I After 573000 nodes, 117241 on tree, 47.658575 best solution, best possible 47.507667 (170.77 seconds)
# Cbc0010I After 574000 nodes, 117226 on tree, 47.658575 best solution, best possible 47.507667 (171.31 seconds)
# Cbc0010I After 575000 nodes, 117224 on tree, 47.658575 best solution, best possible 47.507667 (171.69 seconds)
# Cbc0010I After 576000 nodes, 117217 on tree, 47.658575 best solution, best possible 47.507667 (172.02 seconds)
# Cbc0010I After 577000 nodes, 117213 on tree, 47.658575 best solution, best possible 47.507667 (172.36 seconds)
# Cbc0010I After 578000 nodes, 117202 on tree, 47.658575 best solution, best possible 47.507667 (172.66 seconds)
# Cbc0010I After 579000 nodes, 117193 on tree, 47.658575 best solution, best possible 47.507667 (172.91 seconds)
# Cbc0010I After 580000 nodes, 117187 on tree, 47.658575 best solution, best possible 47.507667 (173.15 seconds)
# Cbc0010I After 581000 nodes, 117179 on tree, 47.658575 best solution, best possible 47.507667 (173.43 seconds)
# Cbc0010I After 582000 nodes, 117176 on tree, 47.658575 best solution, best possible 47.507667 (173.71 seconds)
# Cbc0010I After 583000 nodes, 117549 on tree, 47.658575 best solution, best possible 47.507667 (173.92 seconds)
# Cbc0010I After 584000 nodes, 117546 on tree, 47.658575 best solution, best possible 47.507667 (174.17 seconds)
# Cbc0010I After 585000 nodes, 117533 on tree, 47.658575 best solution, best possible 47.507667 (174.41 seconds)
# Cbc0010I After 586000 nodes, 117535 on tree, 47.658575 best solution, best possible 47.507667 (174.69 seconds)
# Cbc0010I After 587000 nodes, 117527 on tree, 47.658575 best solution, best possible 47.507667 (174.98 seconds)
# Cbc0010I After 588000 nodes, 117510 on tree, 47.658575 best solution, best possible 47.507667 (175.21 seconds)
# Cbc0010I After 589000 nodes, 117507 on tree, 47.658575 best solution, best possible 47.507667 (175.47 seconds)
# Cbc0010I After 590000 nodes, 117499 on tree, 47.658575 best solution, best possible 47.507667 (175.75 seconds)
# Cbc0010I After 591000 nodes, 117497 on tree, 47.658575 best solution, best possible 47.507667 (176.05 seconds)
# Cbc0010I After 592000 nodes, 117489 on tree, 47.658575 best solution, best possible 47.507667 (176.31 seconds)
# Cbc0010I After 593000 nodes, 117482 on tree, 47.658575 best solution, best possible 47.507667 (176.60 seconds)
# Cbc0010I After 594000 nodes, 117473 on tree, 47.658575 best solution, best possible 47.507667 (176.88 seconds)
# Cbc0010I After 595000 nodes, 117471 on tree, 47.658575 best solution, best possible 47.507667 (177.17 seconds)
# Cbc0010I After 596000 nodes, 117461 on tree, 47.658575 best solution, best possible 47.507667 (177.45 seconds)
# Cbc0010I After 597000 nodes, 117449 on tree, 47.658575 best solution, best possible 47.507667 (177.70 seconds)
# Cbc0010I After 598000 nodes, 117449 on tree, 47.658575 best solution, best possible 47.507667 (178.01 seconds)
# Cbc0010I After 599000 nodes, 117440 on tree, 47.658575 best solution, best possible 47.507667 (178.30 seconds)
# Cbc0010I After 600000 nodes, 117426 on tree, 47.658575 best solution, best possible 47.507667 (178.56 seconds)
# Cbc0010I After 601000 nodes, 117423 on tree, 47.658575 best solution, best possible 47.507667 (178.84 seconds)
# Cbc0010I After 602000 nodes, 117417 on tree, 47.658575 best solution, best possible 47.507667 (179.10 seconds)
# Cbc0010I After 603000 nodes, 117407 on tree, 47.658575 best solution, best possible 47.507667 (179.35 seconds)
# Cbc0010I After 604000 nodes, 117402 on tree, 47.658575 best solution, best possible 47.507667 (179.61 seconds)
# Cbc0010I After 605000 nodes, 117397 on tree, 47.658575 best solution, best possible 47.507667 (179.88 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 47.658575 (best possible 47.507667), took 8957555 iterations and 605459 nodes (180.32 seconds)
# Cbc0032I Strong branching done 578296 times (9978649 iterations), fathomed 54966 nodes and fixed 89091 variables
# Cbc0035I Maximum depth 90, 510 variables fixed on reduced cost
# Cuts at root node changed objective from 47.5077 to 47.5077
# Probing was tried 21 times and created 87 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Gomory was tried 21 times and created 195 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Knapsack was tried 21 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Clique was tried 21 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 21 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# FlowCover was tried 21 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# TwoMirCuts was tried 21 times and created 97 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                47.65857515
# Lower bound:                    47.508
# Gap:                            0.00
# Enumerated nodes:               605459
# Total iterations:               8957555
# Time (CPU seconds):             176.07
# Time (Wallclock seconds):       180.33
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       176.08   (Wallclock seconds):       180.35
#
# Optimization successful!
# Optimal objective: $47.66

# %%
# Visualize Smart Charging Results
if results['status'] == 'Optimal':
    # Create comprehensive visualization
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(18, 12))
    
    # Calculate time slots in hours for plotting
    time_slots_hours = [(optimizer.start_date + timedelta(minutes=15*i)).hour + 
                       (optimizer.start_date + timedelta(minutes=15*i)).minute/60 
                       for i in range(optimizer.total_time_slots)]
    
    # Original (uncontrolled) profile - immediate charging at maximum power
    original_profile = np.zeros(optimizer.total_time_slots)
    for _, session in demo_sessions.iterrows():
        start_slot = session['start_slot']
        slots_needed = session['min_slots_needed']
        
        # Immediate charging from arrival using maximum power
        for i in range(min(slots_needed, optimizer.total_time_slots - start_slot)):
            if start_slot + i < optimizer.total_time_slots:
                original_profile[start_slot + i] += 7.0  # Maximum power
    
    # Optimized flexible charging profile
    optimized_profile = np.zeros(optimizer.total_time_slots)
    power_levels_used = []
    
    for session_id in results['charging_schedule']:
        schedule = results['charging_schedule'][session_id]
        for charge_info in schedule:
            slot = charge_info['time_slot']
            power = charge_info['power_kw']
            optimized_profile[slot] += power
            power_levels_used.append(power)
    
    # Plot 1: Original vs Optimized Load Profiles
    ax1.plot(time_slots_hours, original_profile, 'r-', linewidth=2, 
             label='Original (Immediate 7.0 kW)', alpha=0.7)
    ax1.fill_between(time_slots_hours, original_profile, alpha=0.3, color='red')
    
    ax1.plot(time_slots_hours, optimized_profile, 'b-', linewidth=2, 
             label='Optimized (Flexible)', alpha=0.8)
    ax1.fill_between(time_slots_hours, optimized_profile, alpha=0.4, color='blue')
    
    ax1.set_xlabel('Hour of Day')
    ax1.set_ylabel('Aggregate Power (kW)')
    ax1.set_title('Original vs Optimized Flexible Charging Profiles')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim(0, 32)
    
    # Add time period background colors
    for i in range(len(time_slots_hours)):
        hour = time_slots_hours[i]
        time_slot = optimizer.start_date + timedelta(hours=hour)
        period = optimizer.get_time_period(time_slot)
        
        color_map = {'peak': 'red', 'part_peak': 'orange', 'off_peak': 'lightgreen'}
        if period in color_map:
            ax1.axvspan(hour, hour + 0.25, alpha=0.1, color=color_map[period])
    
    # Plot 2: Cost Breakdown
    periods = list(results['total_demand_by_period'].keys())
    demand_costs = [results['total_demand_by_period'][p] for p in periods]
    energy_cost = results['objective_value'] - sum(demand_costs)
    # completion_penalty = 0.01 * sum(results['completion_times'].values())
    
    costs = demand_costs + [energy_cost]
    labels = [p.replace('_', ' ').title() for p in periods] + ['Energy Charges', 'Completion Penalty']
    colors = plt.cm.Set3(np.linspace(0, 1, len(costs)))
    
    ax2.pie([c for c in costs if c > 0.001], 
           labels=[labels[i] for i, c in enumerate(costs) if c > 0.001], 
           colors=colors, autopct='%1.1f%%', startangle=90)
    ax2.set_title(f'Cost Breakdown - Total: ${results["objective_value"]:.2f}')
    
    # # Plot 3: Completion Time Analysis
    # session_names = []
    # completion_times = []
    # earliest_possible = []
    
    # for session_id, completion_time in results['completion_times'].items():
    #     session_info = demo_sessions[demo_sessions['event_id'] == session_id].iloc[0]
    #     session_names.append(f"...{str(session_id)[-3:]}")
    #     completion_times.append(completion_time)
    #     earliest_possible.append(session_info['min_completion_time'])
    
    # x = np.arange(len(session_names))
    # width = 0.35
    
    # bars1 = ax3.bar(x - width/2, earliest_possible, width, label='Earliest Possible', 
    #                color='lightcoral', alpha=0.7)
    # bars2 = ax3.bar(x + width/2, completion_times, width, label='Optimized', 
    #                color='skyblue', alpha=0.7)
    
    # ax3.set_xlabel('Session')
    # ax3.set_ylabel('Completion Time Slot')
    # ax3.set_title('Completion Time Analysis')
    # ax3.set_xticks(x)
    # ax3.set_xticklabels(session_names)
    # ax3.legend()
    # ax3.grid(True, alpha=0.3)
    
    # # Add delay annotations
    # for i, (early, actual) in enumerate(zip(earliest_possible, completion_times)):
    #     delay = actual - early
    #     if delay > 0:
    #         ax3.annotate(f'+{delay:.0f}', xy=(i + width/2, actual), 
    #                     xytext=(0, 5), textcoords='offset points', 
    #                     ha='center', va='bottom', fontsize=8)
    
    # Plot 4: Power vs Time Period Analysis
    power_by_period = {'peak': [], 'part_peak': [], 'off_peak': []}
    
    for session_id in results['charging_schedule']:
        schedule = results['charging_schedule'][session_id]
        for charge_info in schedule:
            period = optimizer.get_time_period(charge_info['time'])
            if period in power_by_period:
                power_by_period[period].append(charge_info['power_kw'])
    
    # Create box plot for power levels by time period
    periods_with_data = [period for period in power_by_period if power_by_period[period]]
    power_data = [power_by_period[period] for period in periods_with_data]
    
    if power_data and any(len(data) > 0 for data in power_data):
        box_plot = ax4.boxplot(power_data, labels=[p.replace('_', '\n') for p in periods_with_data], 
                              patch_artist=True)
        
        # Color the boxes
        colors_box = ['lightcoral', 'lightsalmon', 'lightgreen']
        for patch, color in zip(box_plot['boxes'], colors_box[:len(box_plot['boxes'])]):
            patch.set_facecolor(color)
            patch.set_alpha(0.7)
        
        ax4.set_ylabel('Power Level (kW)')
        ax4.set_title('Power Level Distribution by Time Period')
        ax4.grid(True, alpha=0.3)
        ax4.set_ylim(optimizer.min_power - 0.2, optimizer.max_power + 0.2)
    else:
        # Fallback: simple power histogram
        if power_levels_used:
            ax4.hist(power_levels_used, bins=10, alpha=0.7, color='skyblue', edgecolor='black')
            ax4.set_xlabel('Power Level (kW)')
            ax4.set_ylabel('Frequency')
            ax4.set_title('Power Level Distribution')
            ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Print detailed results
    print("\n" + "="*80)
    print("FLEXIBLE CHARGING OPTIMIZATION RESULTS")
    print("="*80)
    
    true_energy_cost = energy_cost
    print(f"Total Cost (including completion penalty): ${results['objective_value']:.2f}")
    print(f"Energy + Demand Costs: ${results['objective_value']}")
    
    if np.max(original_profile) > 0:
        print(f"\nLoad Profile Analysis:")
        print(f"Original Peak Demand: {np.max(original_profile):.1f} kW")
        print(f"Optimized Peak Demand: {np.max(optimized_profile):.1f} kW")
        print(f"Peak Reduction: {np.max(original_profile) - np.max(optimized_profile):.1f} kW")
        print(f"Peak Reduction %: {((np.max(original_profile) - np.max(optimized_profile))/np.max(original_profile)*100):.1f}%")
    
    if power_levels_used:
        print(f"\nPower Level Statistics:")
        print(f"  Average Power: {np.mean(power_levels_used):.2f} kW")
        print(f"  Min Power Used: {np.min(power_levels_used):.2f} kW")
        print(f"  Max Power Used: {np.max(power_levels_used):.2f} kW")
        print(f"  Power Standard Deviation: {np.std(power_levels_used):.2f} kW")
        
        total_energy = sum(charge['energy_kwh'] for session_id in results['charging_schedule'] 
                          for charge in results['charging_schedule'][session_id])
        print(f"  Total Energy Delivered: {total_energy:.2f} kWh")
    
    # print("\nCompletion Time Analysis:")
    # for session_id, completion_time in results['completion_times'].items():
    #     session_info = demo_sessions[demo_sessions['event_id'] == session_id].iloc[0]
    #     earliest = session_info['min_completion_time']
    #     delay = completion_time - earliest
    #     print(f"  Session {session_id}:")
    #     print(f"    Earliest possible completion: Slot {earliest}")
    #     print(f"    Actual completion: Slot {completion_time}")
    #     print(f"    Delay: {delay:.0f} slots ({delay * 0.25:.1f} hours)")
    
    print("\nDemand Charges by Period:")
    for period, cost in results['total_demand_by_period'].items():
        demand_kw = results['demand_charges'][period]
        rate = optimizer.demand_rates[period]
        print(f"  {period.replace('_', ' ').title()}: {demand_kw:.2f} kW @ ${rate:.2f}/kW = ${cost:.2f}")
    
    print(f"\nEnergy Charges: ${true_energy_cost:.2f}")
    
    print(f"\nOptimal Flexible Charging Schedule:")
    for session_id in results['charging_schedule']:
        session_info = demo_sessions[demo_sessions['event_id'] == session_id].iloc[0]
        schedule = results['charging_schedule'][session_id]
        schedule.sort(key=lambda x: x['time_slot'])
        
        print(f"\nSession {session_id} ({session_info['energy_kwh']:.1f} kWh required):")
        
        # Group consecutive charging periods
        if schedule:
            print(f"  Charging periods:")
            for i, charge_info in enumerate(schedule):
                power = charge_info['power_kw']
                time_str = charge_info['time'].strftime('%H:%M')
                period = optimizer.get_time_period(charge_info['time'])
                rate = optimizer.energy_rates[period]
                
                print(f"    {time_str}: {power:.2f} kW ({period}, ${rate:.4f}/kWh)")

else:
    print("Optimization failed - cannot generate visualizations")
# Out:
# ================================================================================
# FLEXIBLE CHARGING OPTIMIZATION RESULTS
# ================================================================================
# Total Cost (including completion penalty): $47.66
# Energy + Demand Costs: $47.658574847366495
#
# Load Profile Analysis:
# Original Peak Demand: 14.0 kW
# Optimized Peak Demand: 2.1 kW
# Peak Reduction: 11.9 kW
# Peak Reduction %: 85.1%
#
# Power Level Statistics:
#   Average Power: 2.00 kW
#   Min Power Used: 1.65 kW
#   Max Power Used: 2.08 kW
#   Power Standard Deviation: 0.15 kW
#   Total Energy Delivered: 27.97 kWh
#
# Demand Charges by Period:
#   Peak: 0.00 kW @ $18.74/kW = $0.00
#   Part Peak: 1.75 kW @ $5.23/kW = $9.16
#   Anytime: 2.08 kW @ $17.33/kW = $36.08
#
# Energy Charges: $2.42
#
# Optimal Flexible Charging Schedule:
#
# Session 77344924 (7.2 kWh required):
#   Charging periods:
#     19:15: 1.75 kW (part_peak, $0.1071/kWh)
#     19:30: 1.75 kW (part_peak, $0.1071/kWh)
#     19:45: 1.75 kW (part_peak, $0.1071/kWh)
#     20:00: 1.75 kW (part_peak, $0.1071/kWh)
#     20:15: 1.75 kW (part_peak, $0.1071/kWh)
#     20:30: 1.75 kW (part_peak, $0.1071/kWh)
#     20:45: 1.75 kW (part_peak, $0.1071/kWh)
#     21:30: 2.08 kW (off_peak, $0.0806/kWh)
#     22:30: 2.08 kW (off_peak, $0.0806/kWh)
#     23:00: 2.08 kW (off_peak, $0.0806/kWh)
#     23:15: 2.08 kW (off_peak, $0.0806/kWh)
#     23:30: 2.08 kW (off_peak, $0.0806/kWh)
#     23:45: 2.08 kW (off_peak, $0.0806/kWh)
#     00:15: 2.08 kW (off_peak, $0.0806/kWh)
#     00:30: 2.08 kW (off_peak, $0.0806/kWh)
#
# Session 77340858 (12.3 kWh required):
#   Charging periods:
#     18:15: 1.75 kW (part_peak, $0.1071/kWh)
#     18:30: 1.75 kW (part_peak, $0.1071/kWh)
#     21:45: 2.08 kW (off_peak, $0.0806/kWh)
#     22:00: 2.08 kW (off_peak, $0.0806/kWh)
#     22:15: 2.08 kW (off_peak, $0.0806/kWh)
#     22:45: 2.08 kW (off_peak, $0.0806/kWh)
#     00:45: 2.08 kW (off_peak, $0.0806/kWh)
#     01:00: 2.08 kW (off_peak, $0.0806/kWh)
#     01:15: 2.08 kW (off_peak, $0.0806/kWh)
#     01:30: 2.08 kW (off_peak, $0.0806/kWh)
#     01:45: 2.08 kW (off_peak, $0.0806/kWh)
#     03:00: 2.08 kW (off_peak, $0.0806/kWh)
#     03:15: 2.08 kW (off_peak, $0.0806/kWh)
#     03:45: 2.08 kW (off_peak, $0.0806/kWh)
#     05:15: 2.08 kW (off_peak, $0.0806/kWh)
#     05:30: 2.08 kW (off_peak, $0.0806/kWh)
#     05:45: 2.08 kW (off_peak, $0.0806/kWh)
#     06:15: 2.08 kW (off_peak, $0.0806/kWh)
#     06:30: 2.08 kW (off_peak, $0.0806/kWh)
#     06:45: 2.08 kW (off_peak, $0.0806/kWh)
#     07:00: 2.08 kW (off_peak, $0.0806/kWh)
#     07:15: 2.08 kW (off_peak, $0.0806/kWh)
#     07:30: 2.08 kW (off_peak, $0.0806/kWh)
#     07:45: 2.08 kW (off_peak, $0.0806/kWh)
#
# Session 77339080 (8.4 kWh required):
#   Charging periods:
#     18:00: 1.75 kW (part_peak, $0.1071/kWh)
#     18:45: 1.75 kW (part_peak, $0.1071/kWh)
#     19:00: 1.75 kW (part_peak, $0.1071/kWh)
#     21:00: 1.75 kW (part_peak, $0.1071/kWh)
#     21:15: 1.65 kW (part_peak, $0.1071/kWh)
#     00:00: 2.08 kW (off_peak, $0.0806/kWh)
#     02:00: 2.08 kW (off_peak, $0.0806/kWh)
#     02:15: 2.08 kW (off_peak, $0.0806/kWh)
#     02:30: 2.08 kW (off_peak, $0.0806/kWh)
#     02:45: 2.08 kW (off_peak, $0.0806/kWh)
#     03:30: 2.08 kW (off_peak, $0.0806/kWh)
#     04:00: 2.08 kW (off_peak, $0.0806/kWh)
#     04:15: 2.08 kW (off_peak, $0.0806/kWh)
#     04:30: 2.08 kW (off_peak, $0.0806/kWh)
#     04:45: 2.08 kW (off_peak, $0.0806/kWh)
#     05:00: 2.08 kW (off_peak, $0.0806/kWh)
#     06:00: 2.08 kW (off_peak, $0.0806/kWh)

# %%
# Save Results and Export Functions
def export_results_to_csv(results, sessions_df, filename="data/chapter5/optimization_results_flexible_L2.csv"):
    """Export optimization results with flexible L2 charging to CSV for further analysis."""
    if results['status'] != 'Optimal':
        print("Cannot export - optimization was not successful")
        return
    
    export_data = []
    for session_id in results['charging_schedule']:
        session_info = sessions_df[sessions_df['event_id'] == session_id].iloc[0]
        schedule = results['charging_schedule'][session_id]
        
        for charge_info in schedule:
            period = optimizer.get_time_period(charge_info['time'])
            export_data.append({
                'session_id': session_id,
                'original_start': session_info['start_time'],
                'original_end': session_info['end_time'],
                'required_energy_kwh': session_info['energy_kwh'],
                'scheduled_time': charge_info['time'],
                'time_slot': charge_info['time_slot'],
                'optimal_power_kw': charge_info['power_kw'],
                'slot_energy_kwh': charge_info['energy_kwh'],
                'time_period': period,
                'energy_rate_per_kwh': optimizer.energy_rates[period],
                'slot_energy_cost': charge_info['energy_kwh'] * optimizer.energy_rates[period]
            })
    
    export_df = pd.DataFrame(export_data)
    export_df.to_csv(filename, index=False)
    print(f"Results exported to {filename}")
    
    # Summary statistics
    power_levels = export_df['optimal_power_kw'].values
    # completion_delays = export_df.groupby('session_id')['completion_delay_slots'].first().values
    
    print(f"\nExport Summary:")
    print(f"- Total charging time slots: {len(export_df)}")
    print(f"- Power level range: {power_levels.min():.2f} - {power_levels.max():.2f} kW")
    print(f"- Average power level: {power_levels.mean():.2f} kW")
    print(f"- Power level std dev: {power_levels.std():.2f} kW")
    print(f"- Total energy: {export_df['slot_energy_kwh'].sum():.2f} kWh")
    print(f"- Total energy cost: ${export_df['slot_energy_cost'].sum():.2f}")
    
    return export_df

# Export results if optimization was successful
if results['status'] == 'Optimal':
    export_df = export_results_to_csv(results, demo_sessions, "data/chapter5/ev_optimization_flexible_L2_demo_results.csv")
    print("\nFirst few rows of exported data:")
    print(export_df.head().to_string())
# Out:
# Results exported to data/chapter5/ev_optimization_flexible_L2_demo_results.csv
#
# Export Summary:
# - Total charging time slots: 56
# - Power level range: 1.62 - 2.05 kW
# - Average power level: 2.00 kW
# - Power level std dev: 0.10 kW
# - Average completion delay: 28.0 slots
# - Total energy: 27.97 kWh
# - Total energy cost: $2.42
#
# First few rows of exported data:
#    session_id      original_start        original_end  required_energy_kwh  min_completion_time  actual_completion_time  completion_delay_slots      scheduled_time  time_slot  optimal_power_kw  slot_energy_kwh time_period  energy_rate_per_kwh  slot_energy_cost
# 0    77344924 2017-08-01 19:15:00 2017-08-02 01:00:00             7.230203                   81                    91.0                    10.0 2017-08-01 19:15:00         77          1.843835         0.460959   part_peak              0.10714          0.049387
# 1    77344924 2017-08-01 19:15:00 2017-08-02 01:00:00             7.230203                   81                    91.0                    10.0 2017-08-01 19:30:00         78          1.843835         0.460959   part_peak              0.10714          0.049387
# 2    77344924 2017-08-01 19:15:00 2017-08-02 01:00:00             7.230203                   81                    91.0                    10.0 2017-08-01 19:45:00         79          1.843835         0.460959   part_peak              0.10714          0.049387
# 3    77344924 2017-08-01 19:15:00 2017-08-02 01:00:00             7.230203                   81                    91.0                    10.0 2017-08-01 20:00:00         80          1.843835         0.460959   part_peak              0.10714          0.049387
# 4    77344924 2017-08-01 19:15:00 2017-08-02 01:00:00             7.230203                   81                    91.0                    10.0 2017-08-01 20:15:00         81          1.843835         0.460959   part_peak              0.10714          0.049387

# %% [markdown]
# ### In this notebook:
# 1. **MILP Formulation**: How to formulate EV charging as a mixed-integer optimization problem
# 2. **Time-of-Use Optimization**: Shifting charging from peak to off-peak periods reduces costs
# 3. **Demand Charge Management**: Controlling peak demand is crucial for large facilities
# 4. **Real Data Application**: Applied to actual charging session data from AlCoPark garage
#
# ### Potential Extensions:
# 1. **Larger Scale**: Use commercial solvers (Gurobi, CPLEX) for full datasets
# 2. **Uncertainty Handling**: Stochastic programming for uncertain arrival/departure times
# 3. **Demand Response**: Integration with utility demand response programs
# 4. **Real-Time Control**: Rolling horizon optimization for online implementation
#
# ### Computational Considerations:
# - **Problem Size**: Scales as O(sessions × blocks × time_slots)
# - **Solution Time**: Can be significant for large instances
# - **Memory Requirements**: Binary variables consume substantial memory
# - **Alternative Approaches**: Heuristics, decomposition methods for scalability
#
# ### References
# R. Yin, B. Wang and D. Black. “Characteristics of Electric Vehicle Charging Sessions and its
# Benefits in Managing Peak Demands of a Commercial Building”. In: IEEE International Conference
# on Smart Grid Communications (SmartGridComm), Virtual Conference, 11-13 November 2020.
